# %% [raw]
# Author: Shayon Gupta
# Training Ml model

# %%
import nltk

# %%
#defining features
def word_features(word):
    feature = dict(starting_letter = word[0],last_letter = word[-1:],last2_letters = word[-2:],last3_letters = word[-3:])
    return feature

# %%
dictionary = open('English_dictionary.txt','r').readlines()

# %%
dictionary
# Out:
# ['A \n',
#  '\n',
#  '\n',
#  '\n',
#  'A-  prefix (also an- before a vowel sound) not, without (amoral). [greek]\n',
#  '\n',
#  'Aa  abbr. 1 automobile association. 2 alcoholics anonymous. 3 anti-aircraft.\n',
#  '\n',
#  'Aardvark  n. Mammal with a tubular snout and a long tongue, feeding on termites. [afrikaans]\n',
#  '\n',
#  'Ab-  prefix off, away, from (abduct). [latin]\n',
#  '\n',
#  'Aback  adv. \x7f take aback surprise, disconcert. [old english: related to *a2]\n',
#  '\n',
#  'Abacus  n. (pl. -cuses) 1 frame with wires along which beads are slid for calculating. 2 archit. Flat slab on top of a capital. [latin from greek from hebrew]\n',
#  '\n',
#  'Abaft  naut. —adv. In the stern half of a ship. —prep. Nearer the stern than. [from *a2, -baft: see *aft]\n',
#  '\n',
#  "Abandon  —v. 1 give up. 2 forsake, desert. 3 (often foll. By to; often refl.) Yield to a passion, another's control, etc. —n. Freedom from inhibitions. \x7f abandonment n. [french: related to *ad-, *ban]\n",
#  '\n',
#  'Abandoned  adj. 1 deserted, forsaken. 2 unrestrained, profligate.\n',
#  '\n',
#  'Abase  v. (-sing) (also refl.) Humiliate, degrade. \x7f abasement n. [french: related to *ad-, *base2]\n',
#  '\n',
#  'Abashed  predic. Adj. Embarrassed, disconcerted. [french es- *ex-1, baïr astound]\n',
#  '\n',
#  'Abate  v. (-ting) make or become less strong etc.; diminish. \x7f abatement n. [french abatre from latin batt(u)o beat]\n',
#  '\n',
#  'Abattoir  n. Slaughterhouse. [french abatre fell, as *abate]\n',
#  '\n',
#  'Abbacy  n. (pl. -ies) office or jurisdiction of an abbot or abbess. [latin: related to *abbot]\n',
#  '\n',
#  'Abbé  n. (in france) abbot or priest. [french from latin: related to *abbot]\n',
#  '\n',
#  'Abbess  n. Head of a community of nuns.\n',
#  '\n',
#  'Abbey  n. (pl. -s) 1 building(s) occupied by a community of monks or nuns. 2 the community itself. 3 building that was once an abbey.\n',
#  '\n',
#  'Abbot  n. Head of a community of monks. [old english from latin abbas]\n',
#  '\n',
#  'Abbreviate  v. (-ting) shorten, esp. Represent (a word etc.) By a part of it. \x7f abbreviation n. [latin: related to *brief]\n',
#  '\n',
#  'Abc  n. 1 the alphabet. 2 rudiments of a subject. 3 alphabetical guide.\n',
#  '\n',
#  'Abdicate  v. (-ting) 1 (usu. Absol.) Give up or renounce (the throne). 2 renounce (a duty, right, etc.). \x7f abdication n. [latin dico declare]\n',
#  '\n',
#  'Abdomen  n. 1 the belly, including the stomach, bowels, etc. 2 the hinder part of an insect etc. \x7f abdominal adj. [latin]\n',
#  '\n',
#  'Abduct  v. Carry off or kidnap illegally. \x7f abduction n. Abductor n. [latin duco lead]\n',
#  '\n',
#  "Abeam  adv. At right angles to a ship's or an aircraft's length.\n",
#  '\n',
#  'Aberdeen angus  n. Animal of a scottish breed of hornless black cattle. [aberdeen in scotland]\n',
#  '\n',
#  'Aberdonian  —adj. Of aberdeen. —n. Native or citizen of aberdeen. [medieval latin]\n',
#  '\n',
#  'Aberrant  adj. Deviating from what is normal or accepted. [latin: related to *err]\n',
#  '\n',
#  'Aberration  n. 1 aberrant behaviour; moral or mental lapse. 2 biol. Deviation from a normal type. 3 distortion of an image because of a defect in a lens or mirror. 4 astron. Apparent displacement of a celestial body.\n',
#  '\n',
#  'Abet  v. (-tt-) (usu. In aid and abet) encourage or assist (an offender or offence). [french: related to *ad-, *bait]\n',
#  '\n',
#  'Abeyance  n. (usu. Prec. By in, into) temporary disuse. [french: related to *ad-, beer gape]\n',
#  '\n',
#  'Abhor  v. (-rr-) detest; regard with disgust. [latin: related to *horror\n',
#  '\n',
#  'Abhorrence  n. Disgust; detestation.\n',
#  '\n',
#  'Abhorrent  adj. (often foll. By to) disgusting or hateful.\n',
#  '\n',
#  "Abide  v. (-ding; past abided or rarely abode) 1 (usu. In neg.) Tolerate, endure (can't abide him). 2 (foll. By by) a act in accordance with (abide by the rules). B keep (a promise). 3 archaic remain, continue. [old english a- intensive prefix, *bide]\n",
#  '\n',
#  'Abiding  adj. Enduring, permanent.\n',
#  '\n',
#  'Ability  n. (pl. -ies) 1 (often foll. By to + infin.) Capacity or power. 2 cleverness, talent. [french: related to *able]\n',
#  '\n',
#  '-ability  suffix forming nouns of quality from, or corresponding to, adjectives in -able.\n',
#  '\n',
#  'Ab initio  adv. From the beginning. [latin]\n',
#  '\n',
#  'Abject  adj. Miserable, wretched; degraded; despicable. \x7f abjection n. [latin jacio -ject- throw]\n',
#  '\n',
#  'Abjure  v. (-ring) renounce on oath (an opinion, cause, etc.). \x7f abjuration n. [latin juro swear]\n',
#  '\n',
#  'Ablative  gram. —n. Case (in latin) of nouns and pronouns indicating an agent, instrument, or location. —adj. Of or in the ablative. [latin ablatus taken away]\n',
#  '\n',
#  'Ablaze  predic. Adj. & adv. 1 on fire. 2 glittering, glowing. 3 greatly excited.\n',
#  '\n',
#  'Able  adj. (abler, ablest) 1 (often foll. By to + infin.; used esp. In is able, will be able, etc., replacing tenses of can) having the capacity or power (not able to come). 2 talented, clever. \x7f ably adv. [latin habilis]\n',
#  '\n',
#  '-able  suffix forming adjectives meaning: 1 that may or must be (eatable; payable). 2 that can be made the subject of (dutiable; objectionable). 3 relevant to or in accordance with (fashionable; seasonable). [latin -abilis]\n',
#  '\n',
#  'Able-bodied  adj. Fit, healthy.\n',
#  '\n',
#  'Able-bodied seaman  n. Ordinary trained seaman.\n',
#  '\n',
#  'Ablution  n. (usu. In pl.) 1 ceremonial washing of the hands, sacred vessels, etc. 2 colloq. A ordinary bodily washing. B place for this. [latin ablutio from luo lut- wash]\n',
#  '\n',
#  '-ably  suffix forming adverbs corresponding to adjectives in -able.\n',
#  '\n',
#  'Abm  abbr. Anti-ballistic missile.\n',
#  '\n',
#  'Abnegate  v. (-ting) give up or renounce (a pleasure or right etc.). [latin nego deny]\n',
#  '\n',
#  'Abnegation  n. Denial; renunciation of a doctrine.\n',
#  '\n',
#  'Abnormal  adj. Deviating from the norm; exceptional. \x7f abnormality n. (pl. -ies). Abnormally adv. [french: related to *anomalous]\n',
#  '\n',
#  'Abo  (also abo) austral. Slang usu. Offens. —n. (pl. -s) aboriginal. —adj. Aboriginal. [abbreviation]\n',
#  '\n',
#  'Aboard  adv. & prep. On or into (a ship, aircraft, etc.). [from *a2]\n',
#  '\n',
#  'Abode1  n. Dwelling-place. [related to *abide]\n',
#  '\n',
#  'Abode2  see *abide.\n',
#  '\n',
#  'Abolish  v. Put an end to (esp. A custom or institution). [latin aboleo destroy]\n',
#  '\n',
#  'Abolition  n. Abolishing or being abolished. \x7f abolitionist n.\n',
#  '\n',
#  'A-bomb  n. = *atomic bomb. [a for *atomic]\n',
#  '\n',
#  'Abominable  adj. 1 detestable, loathsome. 2 colloq. Very unpleasant (abominable weather). \x7f abominably adv. [latin abominor deprecate]\n',
#  '\n',
#  'Abominable snowman  n. Supposed manlike or bearlike himalayan animal; yeti.\n',
#  '\n',
#  'Abominate  v. (-ting) detest, loathe. \x7f abomination n. [latin: related to *abominable]\n',
#  '\n',
#  'Aboriginal  —adj. 1 indigenous, inhabiting a land from the earliest times, esp. Before the arrival of colonists. 2 (usu. Aboriginal) of australian aborigines. —n. 1 aboriginal inhabitant. 2 (usu. Aboriginal) aboriginal inhabitant of australia. [latin: related to *origin]\n',
#  '\n',
#  'Aborigine  n. (usu. In pl.) 1 aboriginal inhabitant. 2 (usu. Aborigine) aboriginal inhabitant of australia.\n',
#  '\n',
#  'Usage  when referring to the people, aboriginal is preferred for the singular form and aborigines for the plural, although aboriginals is also acceptable.\n',
#  '\n',
#  'Abort  v. 1 miscarry. 2 a effect abortion of (a foetus). B effect abortion in (a mother). 3 end or cause (a project etc.) To end before completion. [latin orior be born]\n',
#  '\n',
#  'Abortion  n. 1 natural or (esp.) Induced expulsion of a foetus from the womb before it is able to survive independently. 2 stunted or deformed creature or thing. 3 failed project or action. \x7f abortionist n.\n',
#  'Aboriginal  —adj. 1 indigenous, inhabiting a land from the earliest times, esp. Before the arrival of colonists. 2 (usu. Aboriginal) of australian aborigines. —n. 1 aboriginal inhabitant. 2 (usu. Aboriginal) aboriginal inhabitant of australia. [latin: related to *origin]\n',
#  '\n',
#  'Aborigine  n. (usu. In pl.) 1 aboriginal inhabitant. 2 (usu. Aborigine) aboriginal inhabitant of australia.\n',
#  '\n',
#  'Usage  when referring to the people, aboriginal is preferred for the singular form and aborigines for the plural, although aboriginals is also acceptable.\n',
#  '\n',
#  'Abort  v. 1 miscarry. 2 a effect abortion of (a foetus). B effect abortion in (a mother). 3 end or cause (a project etc.) To end before completion. [latin orior be born]\n',
#  '\n',
#  'Abortion  n. 1 natural or (esp.) Induced expulsion of a foetus from the womb before it is able to survive independently. 2 stunted or deformed creature or thing. 3 failed project or action. \x7f abortionist n.\n',
#  '\n',
#  'Abortive  adj. Fruitless, unsuccessful.\n',
#  '\n',
#  'Abound  v. 1 be plentiful. 2 (foll. By in, with) be rich; teem. [latin unda wave]\n',
#  '\n',
#  'About  —prep. 1 a on the subject of (a book about birds). B relating to (glad about it). C in relation to (symmetry about a plane). 2 at a time near to (about six). 3 a in, round (walked about the town; a scarf about her neck). B all round from a centre (look about you). 4 at points in (strewn about the house). 5 carried with (no money about me). 6 occupied with (about her business). —adv. 1 a approximately (about ten miles). B colloq. In an understatement (just about had enough). 2 nearby (a lot of flu about). 3 in every direction (look about). 4 on the move; in action (out and about). 5 in rotation or succession (turn and turn about). \x7f be about (or all about) colloq. Have as its essential nature (life is all about having fun). Be about to be on the point of (was about to laugh). [old english]\n',
#  '\n',
#  'About-face  n. & int. = *about-turn, about turn.\n',
#  '\n',
#  'About-turn  —n. 1 turn made so as to face the opposite direction. 2 change of opinion or policy etc. —int. (about turn) mil. Command to make an about-turn.\n',
#  '\n',
#  'Above  —prep. 1 over; on the top of; higher than; over the surface of (head above water; above the din). 2 more than (above twenty people). 3 higher in rank, importance, etc., than. 4 a too great or good for (not above cheating). B beyond the reach of (above my understanding; above suspicion). —adv. 1 at or to a higher point; overhead (the floor above; the sky above). 2 earlier on a page or in a book (as noted above). —adj. Preceding (the above argument). —n. (prec. By the) preceding text (the above shows). \x7f above all most of all, more than anything else. Above oneself conceited, arrogant. [old english: related to *a2]\n',
#  '\n',
#  'Above-board  adj. & adv. Without concealment; open or openly.\n',
#  '\n',
#  'Abracadabra  —int. Supposedly magic word used in conjuring. —n. Spell or charm. [latin from greek]\n',
#  '\n',
#  'Abrade  v. (-ding) scrape or wear away (skin, rock, etc.) By rubbing. [latin rado scrape]\n',
#  '\n',
#  'Abrasion  n. 1 scraping or wearing away (of skin, rock, etc.). 2 resulting damaged area.\n',
#  '\n',
#  'Abrasive  —adj. 1 a tending to rub or graze. B capable of polishing by rubbing or grinding. 2 harsh or hurtful in manner. —n. Abrasive substance.\n',
#  '\n',
#  'Abreast  adv. 1 side by side and facing the same way. 2 (foll. By of) up to date.\n',
#  '\n',
#  'Abridge  v. (-ging) shorten (a book, film, etc.). \x7f abridgement n. [latin: related to *abbreviate]\n',
#  '\n',
#  'Abroad  adv. 1 in or to a foreign country or countries. 2 widely (scatter abroad). 3 in circulation (rumour abroad).\n',
#  '\n',
#  'Abrogate  v. (-ting) repeal, abolish (a law etc.). \x7f abrogation n. [latin rogo propose a law]\n',
#  '\n',
#  'Abrupt  adj. 1 sudden, hasty (abrupt end). 2 (of manner etc.) Curt. 3 steep, precipitous. \x7f abruptly adv. Abruptness n. [latin: related to *rupture]\n',
#  '\n',
#  'Abscess  n. (pl. Abscesses) swelling containing pus. [latin: related to *ab-, *cede]\n',
#  'Abseil  —v. Descend by using a doubled rope coiled round the body and fixed at a higher point. —n. Descent made by abseiling. [german ab down, seil rope]\n',
#  '\n',
#  'Absence  n. 1 being away. 2 time of this. 3 (foll. By of) lack of. \x7f absence of mind inattentiveness. [latin absentia]\n',
#  '\n',
#  'Absent  —adj. 1 not present. 2 not existing; lacking. 3 inattentive. —v.refl. Go, or stay, away. \x7f absently adv. (in sense 3 of adj.).\n',
#  '\n',
#  'Absentee  n. Person not present.\n',
#  '\n',
#  'Absenteeism  n. Absenting oneself from work or school etc., esp. Frequently or illicitly.\n',
#  '\n',
#  'Absentee landlord  n. One who lets a property while living elsewhere.\n',
#  '\n',
#  'Absent-minded  adj. Forgetful or inattentive. \x7f absent-mindedly adv. Absent-mindedness n.\n',
#  '\n',
#  'Absinth  n. 1 wormwood. 2 (usu. Absinthe) aniseed-flavoured liqueur based on this. [french from latin]\n',
#  '\n',
#  'Absolute  —adj. 1 complete, utter (absolute bliss). 2 unconditional (absolute authority). 3 despotic (absolute monarch). 4 not relative or comparative (absolute standard). 5 gram. A (of a construction) syntactically independent of the rest of the sentence, as in dinner being over, we left the table. B (of an adjective or transitive verb) without an expressed noun or object (e.g. The deaf, guns kill). 6 (of a legal decree etc.) Final. —n. Philos. (prec. By the) that which can exist independently of anything else. [latin: related to *absolve]\n',
#  '\n',
#  'Absolutely  adv. 1 completely, utterly. 2 in an absolute sense (god exists absolutely). 3  colloq. (used in reply) quite so; yes.\n',
#  '\n',
#  'Absolute majority  n. Majority over all rivals combined.\n',
#  '\n',
#  'Absolute pitch  n. Ability to recognize or sound any given note.\n',
#  '\n',
#  'Absolute temperature  n. One measured from absolute zero.\n',
#  '\n',
#  'Absolute zero  n. Theoretical lowest possible temperature calculated as –273.15° c (or 0° k).\n',
#  '\n',
#  'Absolution  n. Formal forgiveness of sins.\n',
#  '\n',
#  'Absolutism  n. Principle or practice of absolute government. \x7f absolutist n.\n',
#  '\n',
#  'Absolve  v. (-ving) (often foll. By from, of) set or pronounce free from blame or obligation etc. [latin: related to *solve]\n',
#  '\n',
#  'Absorb  v. 1 incorporate as part of itself or oneself. 2 take in, suck up (liquid, heat, knowledge, etc.). 3 reduce the effect or intensity of; deal easily with (an impact, sound, difficulty, etc.). 4 consume (resources etc.). 5 (often as absorbing adj.) Engross the attention of. [latin sorbeo suck in]\n',
#  '\n',
#  'Absorbent  —adj. Tending to absorb. —n. Absorbent substance or organ.\n',
#  '\n',
#  'Absorption  n. 1 absorbing or being absorbed. 2 mental engrossment. \x7f absorptive adj.\n',
#  '\n',
#  'Abstain  v. 1 (usu. Foll. By from) refrain from indulging (abstained from smoking). 2 decline to vote. [latin teneo tent- hold]\n',
#  '\n',
#  'Abstemious  adj. Moderate or ascetic, esp. In eating and drinking. \x7f abstemiously adv. [latin: related to *ab-, temetum strong drink]\n',
#  '\n',
#  'Abstention  n. Abstaining, esp. From voting. [latin: related to *abstain]\n',
#  '\n',
#  'Abstinence  n. Abstaining, esp. From food or alcohol. \x7f abstinent adj. [french: related to *abstain]\n',
#  '\n',
#  'Abstract  —adj. 1 a of or existing in thought or theory rather than matter or practice; not concrete. B (of a word, esp. A noun) denoting a quality, condition, etc., not a concrete object. 2 (of art) achieving its effect by form and colour rather than by realism. —v. 1 (often foll. By from) extract, remove. 2 summarize. —n. 1 summary. 2 abstract work of art. 3 abstraction or abstract term. [latin: related to *tract1]\n',
#  '\n',
#  'Abstracted  adj. Inattentive, distracted. \x7f abstractedly adv.\n',
#  '\n',
#  'Abstraction  n. 1 abstracting or taking away. 2 abstract or visionary idea. 3 abstract qualities (esp. In art). 4 absent-mindedness.\n',
#  '\n',
#  'Abstruse  adj. Hard to understand, profound. [latin abstrudo -trus- conceal]\n',
#  '\n',
#  'Absurd  adj. Wildly illogical or inappropriate; ridiculous. \x7f absurdity n. (pl. -ies). Absurdly adv. [latin: related to *surd]\n',
#  '\n',
#  'Abta  abbr. Association of british travel agents.\n',
#  '\n',
#  'Abundance  n. 1 plenty; more than enough; a lot. 2 wealth. [latin: related to *abound]\n',
#  'Abundance  n. 1 plenty; more than enough; a lot. 2 wealth. [latin: related to *abound]\n',
#  '\n',
#  'Abundant  adj. 1 plentiful. 2 (foll. By in) rich (abundant in fruit). \x7f abundantly adv.\n',
#  '\n',
#  'Abuse  —v. (-sing) 1 use improperly, misuse. 2 insult verbally. 3 maltreat. —n. 1 misuse. 2 insulting language. 3 unjust or corrupt practice. 4 maltreatment (child abuse). \x7f abuser n. [latin: related to *use]\n',
#  '\n',
#  'Abusive  adj. Insulting, offensive. \x7f abusively adv.\n',
#  '\n',
#  'Abut  v. (-tt-) 1 (foll. By on) (of land) border on. 2 (foll. By on, against) (of a building) touch or lean upon (another). [anglo-latin butta strip of land: related to *butt1]\n',
#  '\n',
#  'Abutment  n. Lateral supporting structure of a bridge, arch, etc.\n',
#  '\n',
#  'Abuzz  adv. & adj. In a state of excitement or activity.\n',
#  '\n',
#  'Abysmal  adj. 1 colloq. Extremely bad (abysmal food). 2 profound, utter (abysmal ignorance). \x7f abysmally adv. [latin: related to *abyss]\n',
#  '\n',
#  'Abyss  n. 1 deep chasm. 2 immeasurable depth (abyss of despair). [latin from greek, = bottomless]\n',
#  '\n',
#  'Ac  abbr. 1 (also ac) alternating current. 2 aircraftman.\n',
#  '\n',
#  'Ac  symb. Actinium.\n',
#  '\n',
#  'A/c  abbr. Account. [account current]\n',
#  '\n',
#  '-ac  suffix forming adjectives often (or only) used as nouns (cardiac; maniac). [latin -acus, greek -akos]\n',
#  '\n',
#  'Acacia  n. Tree with yellow or white flowers, esp. One yielding gum arabic. [latin from greek]\n',
#  '\n',
#  'Academia  n. The academic world; scholastic life.\n',
#  '\n',
#  'Academic  —adj. 1 scholarly, of learning. 2 of no practical relevance; theoretical. —n. Teacher or scholar in a university etc. \x7f academically adv.\n',
#  '\n',
#  'Academician  n. Member of an academy. [french académicien]\n',
#  '\n',
#  'Academy  n. (pl. -ies) 1 place of specialized training (military academy). 2 (usu. Academy) society or institution of distinguished scholars, artists, scientists, etc. (royal academy). 3 scot. Secondary school. [greek akademeia the place in athens where plato taught]\n',
#  '\n',
#  'Acanthus  n. (pl. -thuses) 1 herbaceous plant with spiny leaves. 2 archit. Representation of its leaf. [latin from greek]\n',
#  '\n',
#  'A cappella  adj. & adv. (of choral music) unaccompanied. [italian, = in church style]\n',
#  '\n',
#  'Acas  abbr. Advisory, conciliation, and arbitration service.\n',
#  '\n',
#  'Accede  v. (-ding) (foll. By to) 1 take office, esp. As monarch. 2 assent or agree. [latin: related to *cede]\n',
#  '\n',
#  'Accelerate  v. (-ting) move or cause to move or happen more quickly. \x7f acceleration n. [latin: related to *celerity]\n',
#  '\n',
#  "Accelerator  n. 1 device for increasing speed, esp. The pedal controlling the speed of a vehicle's engine. 2 physics apparatus for imparting high speeds to charged particles.\n",
#  '\n',
#  'Accent  —n. 1 particular (esp. Local or national) mode of pronunciation. 2 distinctive feature or emphasis (accent on speed). 3 prominence given to a syllable by stress or pitch. 4 mark on a letter or word to indicate pitch, stress, or vowel quality. —v. 1 emphasize (a word or syllable etc.). 2 write or print accents on (words etc.). 3 accentuate. [latin cantus song]\n',
#  '\n',
#  'Accentuate  v. (-ting) emphasize, make prominent. \x7f accentuation n. [medieval latin: related to *accent]\n',
#  '\n',
#  'Accept  v. 1 (also absol.) Willingly receive (a thing offered). 2 (also absol.) Answer affirmatively (an offer etc.). 3 regard favourably; treat as welcome (felt accepted). 4 believe, receive (an opinion, explanation, etc.) As adequate or valid. 5 take as suitable (does accept cheques). 6 undertake (an office or duty). [latin capio take]\n',
#  '\n',
#  'Acceptable  adj. 1 worth accepting, welcome. 2 tolerable. \x7f acceptability n. Acceptably adv. [french: related to *accept]\n',
#  '\n',
#  'Acceptance  n. 1 willingness to accept. 2 affirmative answer to an invitation etc. 3 approval, belief (found wide acceptance).\n',
#  '\n',
#  'Access  —n. 1 way of approach or entry (shop with rear access). 2 a right or opportunity to reach or use or visit; admittance (access to secret files, to the prisoner). B accessibility. 3 archaic outburst (an access of anger). —v. 1 computing gain access to (data etc.). 2 accession. [french: related to *accede]\n',
#  'Accessible  adj. (often foll. By to) 1 reachable or obtainable; readily available. 2 easy to understand. \x7f accessibility n.\n',
#  '\n',
#  'Accession  —n. 1 taking office, esp. As monarch. 2 thing added. —v. Record the addition of (a new item) to a library etc.\n',
#  '\n',
#  'Accessory  n. (pl. -ies) 1 additional or extra thing. 2 (usu. In pl.) Small attachment, fitting, or subsidiary item of dress (e.g. Shoes, gloves). 3 (often foll. By to) person who abets or is privy to an (esp. Illegal) act. [medieval latin: related to *accede]\n',
#  '\n',
#  'Access road  n. Road giving access only to the properties along it.\n',
#  '\n',
#  'Access time  n. Computing time taken to retrieve data from storage.\n',
#  '\n',
#  'Accident  n. 1 unfortunate esp. Harmful event, caused unintentionally. 2 event that is unexpected or without apparent cause. \x7f by accident unintentionally. [latin cado fall]\n',
#  '\n',
#  "Accidental  —adj. Happening by chance or accident. —n. Mus. Sign indicating a note's momentary departure from the key signature. \x7f accidentally adv.\n",
#  '\n',
#  'Accident-prone  adj. Clumsy.\n',
#  '\n',
#  'Acclaim  —v. 1 welcome or applaud enthusiastically. 2 hail as (acclaimed him king). —n. Applause, welcome, public praise. [latin acclamo: related to *claim]\n',
#  '\n',
#  "Acclamation  n. 1 loud and eager assent. 2 (usu. In pl.) Shouting in a person's honour.\n",
#  '\n',
#  'Acclimatize  v. (also -ise) (-zing or -sing) adapt to a new climate or conditions. \x7f acclimatization n. [french acclimater: related to *climate]\n',
#  '\n',
#  'Accolade  n. 1 praise given. 2 touch made with a sword at the conferring of a knighthood. [latin collum neck]\n',
#  '\n',
#  'Accommodate  v. (-ting) 1 provide lodging or room for (flat accommodates two). 2 adapt, harmonize, reconcile (must accommodate himself to new ideas). 3 a do favour to, oblige (a person). B (foll. By with) supply (a person) with. [latin: related to *commode]\n',
#  '\n',
#  'Accommodating  adj. Obliging, compliant.\n',
#  '\n',
#  'Accommodation  n. 1 lodgings. 2 adjustment, adaptation. 3 convenient arrangement; settlement, compromise.\n',
#  '\n',
#  'Accommodation address  n. Postal address used by a person unable or unwilling to give a permanent address.\n',
#  '\n',
#  'Accompaniment  n. 1 instrumental or orchestral support for a solo instrument, voice, or group. 2 accompanying thing. \x7f accompanist n. (in sense 1).\n',
#  '\n',
#  'Accompany  v. (-ies, -ied) 1 go with; escort. 2 (usu. In passive; foll. By with, by) be done or found with; supplement. 3 mus. Partner with accompaniment. [french: related to *companion]\n',
#  '\n',
#  'Accomplice  n. Partner in a crime etc. [latin: related to *complex]\n',
#  '\n',
#  'Accomplish  v. Succeed in doing; achieve, complete. [latin: related to *complete]\n',
#  '\n',
#  'Accomplished  adj. Clever, skilled.\n',
#  '\n',
#  'Accomplishment  n. 1 completion (of a task etc.). 2 acquired, esp. Social, skill. 3 thing achieved.\n',
#  '\n',
#  "Accord  —v. 1 (often foll. By with) be consistent or in harmony. 2 grant (permission, a request, etc.); give (a welcome etc.). —n. 1 agreement, consent. 2 mus. & art etc. Harmony. \x7f of one's own accord on one's own initiative; voluntarily. With one accord unanimously. [latin cor cord- heart]\n",
#  '\n',
#  'Accordance  n. \x7f in accordance with in conformity to. \x7f accordant adj.\n',
#  '\n',
#  'According  adv. 1 (foll. By to) a as stated by (according to mary). B in proportion to (lives according to his means). 2 (foll. By as + clause) in a manner or to a degree that varies as (pays according as he is able).\n',
#  '\n',
#  'Accordingly  adv. 1 as circumstances suggest or require (please act accordingly). 2 consequently (accordingly, he left the room).\n',
#  '\n',
#  'Accordion  n. Musical reed instrument with concertina-like bellows, keys, and buttons. \x7f accordionist n. [italian accordare to tune]\n',
#  '\n',
#  'Accost  v. 1 approach and address (a person), esp. Boldly. 2 (of a prostitute) solicit. [latin costa rib]\n',
#  'Accession  —n. 1 taking office, esp. As monarch. 2 thing added. —v. Record the addition of (a new item) to a library etc.\n',
#  '\n',
#  'Accessory  n. (pl. -ies) 1 additional or extra thing. 2 (usu. In pl.) Small attachment, fitting, or subsidiary item of dress (e.g. Shoes, gloves). 3 (often foll. By to) person who abets or is privy to an (esp. Illegal) act. [medieval latin: related to *accede]\n',
#  '\n',
#  'Access road  n. Road giving access only to the properties along it.\n',
#  '\n',
#  'Access time  n. Computing time taken to retrieve data from storage.\n',
#  '\n',
#  'Accident  n. 1 unfortunate esp. Harmful event, caused unintentionally. 2 event that is unexpected or without apparent cause. \x7f by accident unintentionally. [latin cado fall]\n',
#  '\n',
#  "Accidental  —adj. Happening by chance or accident. —n. Mus. Sign indicating a note's momentary departure from the key signature. \x7f accidentally adv.\n",
#  '\n',
#  'Accident-prone  adj. Clumsy.\n',
#  '\n',
#  'Acclaim  —v. 1 welcome or applaud enthusiastically. 2 hail as (acclaimed him king). —n. Applause, welcome, public praise. [latin acclamo: related to *claim]\n',
#  '\n',
#  "Acclamation  n. 1 loud and eager assent. 2 (usu. In pl.) Shouting in a person's honour.\n",
#  '\n',
#  'Acclimatize  v. (also -ise) (-zing or -sing) adapt to a new climate or conditions. \x7f acclimatization n. [french acclimater: related to *climate]\n',
#  '\n',
#  'Accolade  n. 1 praise given. 2 touch made with a sword at the conferring of a knighthood. [latin collum neck]\n',
#  '\n',
#  'Accommodate  v. (-ting) 1 provide lodging or room for (flat accommodates two). 2 adapt, harmonize, reconcile (must accommodate himself to new ideas). 3 a do favour to, oblige (a person). B (foll. By with) supply (a person) with. [latin: related to *commode]\n',
#  '\n',
#  'Accommodating  adj. Obliging, compliant.\n',
#  '\n',
#  'Accommodation  n. 1 lodgings. 2 adjustment, adaptation. 3 convenient arrangement; settlement, compromise.\n',
#  '\n',
#  'Accommodation address  n. Postal address used by a person unable or unwilling to give a permanent address.\n',
#  '\n',
#  'Accompaniment  n. 1 instrumental or orchestral support for a solo instrument, voice, or group. 2 accompanying thing. \x7f accompanist n. (in sense 1).\n',
#  '\n',
#  'Accompany  v. (-ies, -ied) 1 go with; escort. 2 (usu. In passive; foll. By with, by) be done or found with; supplement. 3 mus. Partner with accompaniment. [french: related to *companion]\n',
#  '\n',
#  'Accomplice  n. Partner in a crime etc. [latin: related to *complex]\n',
#  '\n',
#  'Accomplish  v. Succeed in doing; achieve, complete. [latin: related to *complete]\n',
#  '\n',
#  'Accomplished  adj. Clever, skilled.\n',
#  '\n',
#  'Accomplishment  n. 1 completion (of a task etc.). 2 acquired, esp. Social, skill. 3 thing achieved.\n',
#  '\n',
#  "Accord  —v. 1 (often foll. By with) be consistent or in harmony. 2 grant (permission, a request, etc.); give (a welcome etc.). —n. 1 agreement, consent. 2 mus. & art etc. Harmony. \x7f of one's own accord on one's own initiative; voluntarily. With one accord unanimously. [latin cor cord- heart]\n",
#  '\n',
#  'Accordance  n. \x7f in accordance with in conformity to. \x7f accordant adj.\n',
#  '\n',
#  'According  adv. 1 (foll. By to) a as stated by (according to mary). B in proportion to (lives according to his means). 2 (foll. By as + clause) in a manner or to a degree that varies as (pays according as he is able).\n',
#  '\n',
#  'Accordingly  adv. 1 as circumstances suggest or require (please act accordingly). 2 consequently (accordingly, he left the room).\n',
#  '\n',
#  'Accordion  n. Musical reed instrument with concertina-like bellows, keys, and buttons. \x7f accordionist n. [italian accordare to tune]\n',
#  '\n',
#  'Accost  v. 1 approach and address (a person), esp. Boldly. 2 (of a prostitute) solicit. [latin costa rib]\n',
#  '\n',
#  'Account  —n. 1 narration, description (an account of his trip). 2 arrangement at a bank etc. For depositing and withdrawing money, credit, etc. (open an account). 3 record or statement of financial transactions with the balance (kept detailed accounts). —v. Consider as (account him wise, a fool).\n',
#  "Accountable  adj. 1 responsible; required to account for one's conduct. 2 explicable, understandable. \x7f accountability n.\n",
#  '\n',
#  'Accountant  n. Professional keeper or verifier of accounts. \x7f accountancy n. Accounting n.\n',
#  '\n',
#  "Accouterments  n.pl. (brit. Accoutrements) 1 equipment, trappings. 2 soldier's equipment excluding weapons and clothes. [french]\n",
#  '\n',
#  "Accoutrements  n.pl. (us accouterments) 1 equipment, trappings. 2 soldier's equipment excluding weapons and clothes. [french]\n",
#  '\n',
#  'Accredit  v. (-t-) 1 (foll. By to) attribute (a saying etc.) To (a person). 2 (foll. By with) credit (a person) with (a saying etc.). 3 (usu. Foll. By to or at) send (an ambassador etc.) With credentials. 4 gain influence for or make credible (an adviser, a statement, etc.). [french: related to *credit]\n',
#  '\n',
#  'Accredited  adj. 1 officially recognized. 2 generally accepted.\n',
#  '\n',
#  'Accretion  n. 1 growth or increase by accumulation, addition, or organic enlargement. 2 the resulting whole. 3 a matter so added. B adhesion of this to the core matter. [latin cresco cret- grow]\n',
#  '\n',
#  'Accrue  v. (-ues, -ued, -uing) (often foll. By to) come as a natural increase or advantage, esp. Financial. [latin: related to *accretion]\n',
#  '\n',
#  'Accumulate  v. (-ting) 1 acquire an increasing number or quantity of; amass, collect. 2 grow numerous; increase. [latin: related to *cumulus]\n',
#  '\n',
#  'Accumulation  n. 1 accumulating or being accumulated. 2 accumulated mass. 3 growth of capital by continued interest. \x7f accumulative adj.\n',
#  '\n',
#  'Accumulator  n. 1 rechargeable electric cell. 2 bet placed on a sequence of events, with the winnings and stake from each placed on the next.\n',
#  '\n',
#  'Accuracy  n. Exactness or careful precision. [latin cura care]\n',
#  '\n',
#  'Accurate  adj. Careful, precise; conforming exactly with the truth or a standard. \x7f accurately adv.\n',
#  '\n',
#  'Accursed  adj. 1 under a curse. 2 colloq. Detestable, annoying. [old english a- intensive prefix, *curse]\n',
#  '\n',
#  'Accusation  n. Accusing or being accused. [french: related to *accuse]\n',
#  '\n',
#  'Accusative  gram. —n. Case expressing the object of an action. —adj. Of or in this case.\n',
#  '\n',
#  'Accusatory  adj. Of or implying accusation.\n',
#  '\n',
#  'Accuse  v. (-sing) (often foll. By of) charge with a fault or crime; blame. [latin accusare: related to *cause]\n',
#  '\n',
#  'Accustom  v. (foll. By to) make used to (accustomed him to hardship). [french: related to *custom]\n',
#  '\n',
#  'Accustomed  adj. 1 (usu. Foll. By to) used to a thing. 2 customary, usual.\n',
#  '\n',
#  'Ace  —n. 1 playing-card etc. With a single spot and generally signifying ‘one’. 2 a person who excels in some activity. B pilot who has shot down many enemy aircraft. 3 (in tennis) unreturnable stroke (esp. A service). —adj. Slang excellent. \x7f within an ace of on the verge of. [latin as unity]\n',
#  '\n',
#  'Acellular  adj. Having no cells; not consisting of cells.\n',
#  'Aceous  suffix forming adjectives in the sense ‘of the nature of’, esp. In the natural sciences (herbaceous). [latin -aceus]\n',
#  '\n',
#  'Acerbic  adj. Harsh and sharp, esp. In speech or manner. \x7f acerbity n. (pl. -ies). [latin acerbus sour]\n',
#  '\n',
#  'Acetaldehyde  n. Colourless volatile liquid aldehyde. [from *acetic, *aldehyde]\n',
#  '\n',
#  'Acetate  n. 1 salt or ester of acetic acid, esp. The cellulose ester. 2 fabric made from this.\n',
#  '\n',
#  'Acetic  adj. Of or like vinegar. [latin acetum vinegar]\n',
#  '\n',
#  'Acetic acid  n. Clear liquid acid giving vinegar its characteristic taste.\n',
#  '\n',
#  'Acetone  n. Colourless volatile liquid that dissolves organic compounds, esp. Paints, varnishes, etc.\n',
#  '\n',
#  'Acetylene  n. Hydrocarbon gas burning with a bright flame, used esp. In welding.\n',
#  '\n',
#  'Ache  —n. 1 continuous dull pain. 2 mental distress. —v. (-ching) suffer from or be the source of an ache. [old english]\n',
#  '\n',
#  'Achieve  v. (-ving) 1 reach or attain, esp. By effort (achieved victory; achieved notoriety). 2 accomplish (a feat or task). [french achever: related to *chief]\n',
#  '\n',
#  'Achievement  n. 1 something achieved. 2 act of achieving.\n',
#  '\n',
#  "Achilles heel  n. Person's weak or vulnerable point. [achilles, greek hero in the iliad]\n",
#  '\n',
#  'Achilles tendon  n. Tendon connecting the heel with the calf muscles.\n',
#  '\n',
#  'Achromatic  adj. Optics 1 transmitting light without separation into constituent colours (achromatic lens). 2 without colour. \x7f achromatically adv. [french: related to *a-, *chrome]\n',
#  '\n',
#  'Achy  adj. (-ier, -iest) full of or suffering from aches.\n',
#  '\n',
#  'Acid  —n. 1 a any of a class of substances that liberate hydrogen ions in water, are usu. Sour and corrosive, turn litmus red, and have a ph of less than 7. B any compound or atom donating protons. 2 any sour substance. 3 slang the drug lsd. —adj. 1 sour. 2 biting, sharp (an acid wit). 3 chem. Having the essential properties of an acid. \x7f acidic adj. Acidify v. (-ies, -ied). Acidity n. Acidly adv. [latin aceo be sour]\n',
#  '\n',
#  'Acid house  n. A type of synthesized music with a simple repetitive beat, often associated with hallucinogenic drugs.\n',
#  '\n',
#  'Acid rain  n. Acid, esp. From industrial waste gases, falling with rain.\n',
#  '\n',
#  'Acid test  n. Severe or conclusive test.\n',
#  '\n',
#  'Acidulous  adj. Somewhat acid.\n',
#  '\n',
#  "Ack-ack  colloq. —adj. Anti-aircraft. —n. Anti-aircraft gun etc. [formerly signallers' term for aa]\n",
#  '\n',
#  'Acknowledge  v. (-ging) 1 recognize; accept the truth of (acknowledged its failure). 2 confirm the receipt of (a letter etc.). 3 a show that one has noticed (acknowledged my arrival with a grunt). B express appreciation of (a service etc.). 4 recognize the validity of, own (the acknowledged king). [from *ad-, *knowledge]\n',
#  '\n',
#  "Acknowledgement  n. 1 act of acknowledging. 2 a thing given or done in gratitude. B letter confirming receipt of something. 3 (usu. In pl.) Author's statement of gratitude, prefacing a book.\n",
#  '\n',
#  'Acme  n. Highest point (of achievement etc.). [greek]\n',
#  '\n',
#  'Acne  n. Skin condition with red pimples. [latin]\n',
#  '\n',
#  'Acolyte  n. 1 person assisting a priest. 2 assistant; beginner. [greek akolouthos follower]\n',
#  '\n',
#  'Aconite  n. 1 any of various poisonous plants, esp. Monkshood. 2 drug from these. [greek akoniton]\n',
#  '\n',
#  'Acorn  n. Fruit of the oak, with a smooth nut in a cuplike base. [old english]\n',
#  '\n',
#  'Acoustic  adj. 1 of sound or the sense of hearing. 2 (of a musical instrument etc.) Without electrical amplification (acoustic guitar). \x7f acoustically adv. [greek akouo hear]\n',
#  '\n',
#  'Acoustics  n.pl. 1 properties or qualities (of a room etc.) In transmitting sound. 2 (usu. As sing.) Science of sound.\n',
#  '\n',
#  'Acquaint  v. (usu. Foll. By with) make aware of or familiar with (acquaint me with the facts). \x7f be acquainted with have personal knowledge of; know slightly. [latin: related to *ad-, *cognizance]\n',
#  '\n',
#  'Acquaintance  n. 1 being acquainted. 2 person one knows slightly. \x7f acquaintanceship n.\n',
#  'Acquiesce  v. (-cing) 1 agree, esp. By default. 2 (foll. By in) accept (an arrangement etc.). \x7f acquiescence n. Acquiescent adj. [latin: related to *ad-, *quiet]\n',
#  '\n',
#  'Acquire  v. (-ring) gain for oneself; come into possession of. [latin: related to *ad-, quaero quisit- seek]\n',
#  '\n',
#  'Acquired immune deficiency syndrome  see *aids.\n',
#  '\n',
#  'Acquired taste  n. 1 liking developed by experience. 2 object of this.\n',
#  '\n',
#  'Acquirement  n. Thing acquired, esp. A mental attainment.\n',
#  '\n',
#  'Acquisition  n. 1 thing acquired, esp. When useful. 2 acquiring or being acquired. [latin: related to *acquire]\n',
#  '\n',
#  'Acquisitive  adj. Keen to acquire things.\n',
#  '\n',
#  'Acquit  v. (-tt-) 1 (often foll. By of) declare not guilty. 2 refl. A behave or perform in a specified way (acquitted herself well). B (foll. By of) discharge (a duty or responsibility). \x7f acquittal n. [latin: related to *ad-, *quit]\n',
#  '\n',
#  'Acre  n. Measure of land, 4,840 sq. Yds., 0.405 ha. [old english]\n',
#  '\n',
#  'Acreage  n. A number of acres; extent of land.\n',
#  '\n',
#  'Acrid  adj. (-er, -est) bitterly pungent. \x7f acridity n. [latin acer keen, pungent]\n',
#  '\n',
#  'Acrimonious  adj. Bitter in manner or temper. \x7f acrimony n.\n',
#  '\n',
#  'Acrobat  n. Entertainer performing gymnastic feats. \x7f acrobatic adj. Acrobatically adv. [greek akrobates from akron summit, baino walk]\n',
#  '\n',
#  'Acrobatics  n.pl. 1 acrobatic feats. 2 (as sing.) Art of performing these.\n',
#  '\n',
#  'Acronym  n. Word formed from the initial letters of other words (e.g. Laser, nato). [greek akron end, onoma name]\n',
#  '\n',
#  'Acropolis  n. Citadel of an ancient greek city. [greek akron summit, polis city]\n',
#  '\n',
#  'Across  —prep. 1 to or on the other side of (across the river). 2 from one side to another side of (spread across the floor). 3 at or forming an angle with (a stripe across the flag). —adv. 1 to or on the other side (ran across). 2 from one side to another (stretched across). \x7f across the board applying to all. [french à, en, croix: related to *cross]\n',
#  '\n',
#  'Acrostic  n. Poem etc. In which certain letters (usu. The first and last in each line) form a word or words. [greek akron end, stikhos row]\n',
#  '\n',
#  'Acrylic  —adj. Of synthetic material made from acrylic acid. —n. Acrylic fibre or fabric. [latin acer pungent, oleo to smell]\n',
#  '\n',
#  'Acrylic acid  n. A pungent liquid organic acid.\n',
#  '\n',
#  "Act  —n. 1 something done; a deed. 2 process of doing (caught in the act). 3 item of entertainment. 4 pretence (all an act). 5 main division of a play etc. 6 a decree of a legislative body. B document attesting a legal transaction. —v. 1 behave (acted wisely). 2 perform an action or function; take action (act as referee; brakes failed to act; he acted quickly). 3 (also foll. By on) have an effect (alcohol acts on the brain). 4 a perform a part in a play, film, etc. B pretend. 5 a play the part of (acted othello; acts the fool). B perform (a play etc.). C portray (an incident) by actions. \x7f act for be the (esp. Legal) representative of. Act of god natural event, e.g. An earthquake. Act up colloq. Misbehave; give trouble (car is acting up). Get one's act together slang become properly organized; prepare. Put on an act colloq. Make a pretence. [latin ago act- do]\n",
#  '\n',
#  'Acting  —n. Art or occupation of an actor. —attrib. Adj. Serving temporarily or as a substitute (acting manager).\n',
#  '\n',
#  'Actinism  n. Property of short-wave radiation that produces chemical changes, as in photography. [greek aktis ray]\n',
#  '\n',
#  'Actinium  n. Chem. Radioactive metallic element found in pitchblende. [as *actinism]\n',
#  '\n',
#  'Action  n. 1 process of doing or acting (demanded action). 2 forcefulness or energy. 3 exertion of energy or influence (action of acid on metal). 4 deed, act (not aware of his actions). 5 (the action) a series of events in a story, play, etc. B slang exciting activity (missed the action). 6 battle, fighting (killed in action). 7 a mechanism of an instrument. B style of movement of an animal or human. 8 lawsuit. \x7f out of action not working. [latin: related to *act]\n',
#  'Actionable  adj. Giving cause for legal action.\n',
#  '\n',
#  'Action-packed  adj. Full of action or excitement.\n',
#  '\n',
#  'Action point  n. Proposal for action.\n',
#  '\n',
#  'Action replay  n. Playback of part of a television broadcast, esp. A sporting event, often in slow motion.\n',
#  '\n',
#  'Action stations  n.pl. Positions taken up by troops etc. Ready for battle.\n',
#  '\n',
#  'Activate  v. (-ting) 1 make active. 2 chem. Cause reaction in. 3 make radioactive.\n',
#  '\n',
#  'Active  —adj. 1 marked by action; energetic; diligent (an active life). 2 working, operative (active volcano). 3 not merely passive or inert; positive (active support; active ingredients). 4 radioactive. 5 gram. Designating the form of a verb whose subject performs the action (e.g. Saw in he saw a film). —n. Gram. Active form or voice of a verb. \x7f actively adv. [latin: related to *act]\n',
#  '\n',
#  'Active service  n. Military service in wartime.\n',
#  '\n',
#  'Activism  n. Policy of vigorous action, esp. For a political cause. \x7f activist n.\n',
#  '\n',
#  'Activity  n. (pl. -ies) 1 being active; busy or energetic action. 2 (often in pl.) Occupation or pursuit (outdoor activities). 3 = *radioactivity.\n',
#  '\n',
#  'Actor  n. Person who acts in a play, film, etc. [latin: related to *act]\n',
#  '\n',
#  'Actress  n. Female actor.\n',
#  '\n',
#  'Actual  adj. (usu. Attrib.) 1 existing in fact; real. 2 current. [latin: related to *act]\n',
#  '\n',
#  'Actuality  n. (pl. -ies) 1 reality. 2 (in pl.) Existing conditions.\n',
#  '\n',
#  'Actually  adv. 1 as a fact, really (not actually very rich). 2 strange as it may seem (he actually refused!).\n',
#  '\n',
#  'Actuary  n. (pl. -ies) statistician, esp. One calculating insurance risks and premiums. \x7f actuarial adj. [latin actuarius bookkeeper]\n',
#  '\n',
#  'Actuate  v. (-ting) 1 cause (a machine etc.) To move or function. 2 cause (a person) to act. [latin]\n',
#  '\n',
#  'Acuity  n. Sharpness, acuteness. [medieval latin: related to *acute]\n',
#  '\n',
#  'Acumen  n. Keen insight or discernment. [latin, = *acute thing]\n',
#  '\n',
#  'Acupuncture  n. Medical treatment using needles in parts of the body. \x7f acupuncturist n. [latin acu with needle]\n',
#  '\n',
#  'Acute  —adj. (acuter, acutest) 1 serious, severe (acute hardship). 2 (of senses etc.) Keen, penetrating. 3 shrewd. 4 (of a disease) coming quickly to a crisis. 5 (of an angle) less than 90°. 6 (of a sound) high, shrill. —n. = *acute accent. \x7f acutely adv. [latin acutus pointed]\n',
#  '\n',
#  'Acute accent  n. Diacritical mark (´) placed over certain letters in french etc., esp. To show pronunciation.\n',
#  '\n',
#  '-acy  suffix forming nouns of state or quality (accuracy; piracy), or an instance of it (conspiracy; fallacy). [french -acie, latin -acia, -atia, greek -ateia]\n',
#  '\n',
#  'Ad  abbr. Of the christian era. [*anno domini]\n',
#  '\n',
#  'Ad  n. Colloq. Advertisement. [abbreviation]\n',
#  '\n',
#  'Ad-  prefix (altered or assimilated before some letters) implying motion or direction to, reduction or change into, addition, adherence, increase, or intensification. [latin]\n',
#  '\n',
#  'Adage  n. Traditional maxim, proverb. [french from latin]\n',
#  '\n',
#  'Adagio  mus. —adv. & adj. In slow time. —n. (pl. -s) such a movement or passage. [italian]\n',
#  '\n',
#  'Adam  n. The first man. \x7f not know a person from adam be unable to recognize a person. [hebrew, = man]\n',
#  '\n',
#  'Adamant  adj. Stubbornly resolute; unyielding. \x7f adamantly adv. [greek adamas adamant- untameable]\n',
#  '\n',
#  "Adam's apple  n. Projection of cartilage at the front of the neck.\n",
#  '\n',
#  'Adapt  v. 1 a (foll. By to) fit, adjust (one thing to another). B (foll. By to, for) make suitable for a purpose. C modify (esp. A text for broadcasting etc.). 2 (also refl., usu. Foll. By to) adjust to new conditions. \x7f adaptable adj. Adaptation n. [latin: related to *ad-, *apt]\n',
#  'Adaptor  n. 1 device for making equipment compatible. 2 device for connecting several electrical plugs to one socket.\n',
#  '\n',
#  'Add  v. 1 join (one thing to another) as an increase or supplement. 2 put together (numbers) to find their total. 3 say further. \x7f add in include. Add up 1 find the total of. 2 (foll. By to) amount to. 3 colloq. Make sense. [latin addo]\n',
#  '\n',
#  'Addendum  n. (pl. -da) 1 thing to be added. 2 material added at the end of a book.\n',
#  '\n',
#  'Adder  n. Small venomous snake, esp. The common viper. [old english, originally nadder]\n',
#  '\n',
#  'Addict  n. 1 person addicted, esp. To a drug. 2 colloq. Devotee (film addict). [latin: related to *ad-, dico say]\n',
#  '\n',
#  'Addicted  adj. 1 (usu. Foll. By to) dependent on a drug etc. As a habit. 2 devoted to an interest. \x7f addiction n.\n',
#  '\n',
#  'Addictive  adj. Causing addiction.\n',
#  '\n',
#  'Addition  n. 1 adding. 2 person or thing added. \x7f in addition (often foll. By to) also, as well (as). [latin: related to *add]\n',
#  '\n',
#  'Additional  adj. Added, extra, supplementary. \x7f additionally adv.\n',
#  '\n',
#  'Additive  n. Substance added to improve another, esp. To colour, flavour, or preserve food. [latin: related to *add]\n',
#  '\n',
#  'Addle  v. (-ling) 1 muddle, confuse. 2 (usu. As addled adj.) (of an egg) become rotten. [old english, = filth]\n',
#  '\n',
#  "Address  —n. 1 a place where a person lives or an organization is situated. B particulars of this, esp. For postal purposes. C computing location of an item of stored information. 2 discourse to an audience. —v. 1 write postal directions on (an envelope etc.). 2 direct (remarks etc.). 3 speak or write to, esp. Formally. 4 direct one's attention to. 5 golf take aim at (the ball). \x7f address oneself to 1 speak or write to. 2 attend to. [french: related to *ad-, *direct]\n",
#  '\n',
#  'Addressee  n. Person to whom a letter etc. Is addressed.\n',
#  '\n',
#  'Adduce  v. (-cing) cite as an instance or as proof or evidence. \x7f adducible adj. [latin: related to *ad-, duco lead]\n',
#  '\n',
#  'Adenoids  n.pl. Area of enlarged lymphatic tissue between the nose and the throat, often hindering breathing in the young. \x7f adenoidal adj. [greek aden gland]\n',
#  '\n',
#  'Adept  —adj. (foll. By at, in) skilful. —n. Adept person. [latin adipiscor adept- attain]\n',
#  '\n',
#  'Adequate  adj. Sufficient, satisfactory. \x7f adequacy n. Adequately adv. [latin: related to *ad-, *equate]\n',
#  '\n',
#  'À deux  adv. & adj. For or between two. [french]\n',
#  '\n',
#  'Adhere  v. (-ring) 1 (usu. Foll. By to) stick fast to a substance etc. 2 (foll. By to) behave according to (a rule, undertaking, etc.). 3 (foll. By to) give allegiance. [latin haereo stick]\n',
#  '\n',
#  'Adherent  —n. Supporter. —adj. Sticking, adhering. \x7f adherence n.\n',
#  '\n',
#  'Adhesion  n. 1 adhering. 2 unnatural union of body tissues due to inflammation.\n',
#  '\n',
#  'Adhesive  —adj. Sticky, causing adhesion. —n. Adhesive substance. \x7f adhesiveness n.\n',
#  '\n',
#  'Ad hoc  adv. & adj. For one particular occasion or use. [latin]\n',
#  '\n',
#  'Adieu  int. Goodbye. [french, = to god]\n',
#  '\n',
#  'Ad infinitum  adv. Without limit; for ever. [latin]\n',
#  '\n',
#  'Adipose  adj. Of fat; fatty (adipose tissue). \x7f adiposity n. [latin adeps fat]\n',
#  '\n',
#  'Adjacent  adj. (often foll. By to) lying near; adjoining. \x7f adjacency n. [latin jaceo lie]\n',
#  '\n',
#  'Adjective  n. Word used to describe or modify a noun or pronoun. \x7f adjectival adj. [latin jaceo lie]\n',
#  '\n',
#  'Adjoin  v. Be next to and joined with. [latin jungo join]\n',
#  '\n',
#  'Adjourn  v. 1 put off, postpone; break off (a meeting etc.) Temporarily. 2 (of a meeting) break and disperse or (foll. By to) transfer to another place (adjourned to the pub). \x7f adjournment n. [latin: related to *ad-, diurnum day]\n',
#  '\n',
#  'Adjudge  v. (-ging) 1 pronounce judgement on (a matter). 2 pronounce or award judicially. \x7f adjudgement n. (also adjudgment). [latin judex judge]\n',
#  'Adjudicate  v. (-ting) 1 act as judge in a competition, court, etc. 2 adjudge. \x7f adjudication n. Adjudicative adj. Adjudicator n.\n',
#  '\n',
#  'Adjunct  n. 1 (foll. By to, of) subordinate or incidental thing. 2 gram. Word or phrase used to explain or amplify the predicate, subject, etc. [latin: related to *adjoin]\n',
#  '\n',
# ...
#  '\n',
#  'Adonis  n. Handsome young man. [latin, name of a youth loved by venus]\n',
#  '\n',
#  "Adopt  v. 1 legally take (a person) into a relationship, esp. Another's child as one's own. 2 choose (a course of action etc.). 3 take over (another's idea etc.). 4 choose as a candidate for office. 5 accept responsibility for the maintenance of (a road etc.). 6 accept or approve (a report, accounts, etc.). \x7f adoption n. [latin: related to *ad-, *opt]\n",
#  'Adoptive  adj. Because of adoption (adoptive son). [latin: related to *adopt]\n',
#  '\n',
#  'Adorable  adj. 1 deserving adoration. 2 colloq. Delightful, charming.\n',
#  '\n',
#  'Adore  v. (-ring) 1 love intensely. 2 worship as divine. 3 colloq. Like very much. \x7f adoration n. Adorer n. [latin adoro worship]\n',
#  '\n',
#  'Adorn  v. Add beauty to; decorate. \x7f adornment n. [latin: related to *ad-, orno decorate]\n',
#  '\n',
#  'Adrenal  —adj. 1 at or near the kidneys. 2 of the adrenal glands. —n. (in full adrenal gland) either of two ductless glands above the kidneys, secreting adrenalin. [from *ad-, *renal]\n',
#  '\n',
#  'Adrenalin  n. (also adrenaline) 1 stimulative hormone secreted by the adrenal glands. 2 this extracted or synthesized for medicinal use.\n',
#  '\n',
#  'Adrift  adv. & predic.adj. 1 drifting. 2 powerless; aimless. 3 colloq. A unfastened. B out of order, wrong (plans went adrift).\n',
#  '\n',
#  'Adroit  adj. Dexterous, skilful. [french à droit according to right]\n',
#  '\n',
#  'Adsorb  v. (usu. Of a solid) hold (molecules of a gas or liquid etc.) To its surface, forming a thin film. \x7f adsorbent adj. & n. Adsorption n. [from *ad-, *absorb]\n',
#  '\n',
#  'Adulation  n. Obsequious flattery. [latin adulor fawn on]\n',
#  '\n',
#  'Adult  —adj. 1 mature, grown-up. 2 (attrib.) Of or for adults (adult education). —n. Adult person. \x7f adulthood n. [latin adolesco adultus grow up]\n',
#  '\n',
#  'Adulterate  v. (-ting) debase (esp. Foods) by adding other substances. \x7f adulterant adj. & n. Adulteration n. [latin adultero corrupt]\n',
#  '\n',
#  'Adulterer  n. (fem. Adulteress) person who commits adultery.\n',
#  '\n',
#  'Adultery  n. Voluntary sexual intercourse between a married person and a person other than his or her spouse. \x7f adulterous adj.\n',
#  '\n',
#  'Adumbrate  v. (-ting) 1 indicate faintly or in outline. 2 foreshadow. 3 overshadow. \x7f adumbration n. [latin: related to *ad-, umbra shade]\n',
#  '\n',
#  'Advance  —v. (-cing) 1 move or put forward; progress. 2 pay or lend (money) beforehand. 3 promote (a person, cause, etc.). 4 present (a suggestion etc.). 5 (as advanced adj.) A well ahead. B socially progressive. —n. 1 going forward; progress. 2 prepayment; loan. 3 (in pl.) Amorous approaches. 4 rise in price. —attrib. Adj. Done or supplied beforehand (advance warning). \x7f advance on approach threateningly. In advance ahead in place or time. [latin: related to *ab-, ante before]\n',
#  '\n',
#  'Advanced level  n. High level of gce examination.\n',
#  '\n',
#  'Advancement  n. Promotion of a person, cause, or plan.\n',
#  '\n',
#  'Advantage  —n. 1 beneficial feature. 2 benefit, profit. 3 (often foll. By over) superiority. 4 (in tennis) the next point after deuce. —v. (-ging) benefit, favour. \x7f take advantage of 1 make good use of. 2 exploit, esp. Unfairly. 3 euphem. Seduce. \x7f advantageous adj. [french: related to *advance]\n',
#  '\n',
#  'Advent  n. 1 season before christmas. 2 coming of christ. 3 (advent) important arrival. [latin adventus from venio come]\n',
#  '\n',
#  'Adventist  n. Member of a christian sect believing in the imminent second coming of christ.\n',
#  '\n',
#  'Adventitious  adj. 1 accidental, casual. 2 added from outside. 3 biol. Formed accidentally or under unusual conditions. [latin: related to *advent]\n',
#  '\n',
#  'Adventure  —n. 1 unusual and exciting experience. 2 enterprise (spirit of adventure). —v. (-ring) dare, venture; engage in adventure. [latin: related to *advent]\n',
#  '\n',
#  'Adventure playground  n. Playground with climbing-frames, building blocks, etc.\n',
#  '\n',
#  'Adventurer  n. (fem. Adventuress) 1 person who seeks adventure, esp. For personal gain or enjoyment. 2 financial speculator.\n',
#  '\n',
#  'Adventurous  adj. Venturesome, enterprising.\n',
#  'Adverb  n. Word indicating manner, degree, circumstance, etc., used to modify an adjective, verb, or other adverb (e.g. Gently, quite, then). \x7f adverbial adj. [latin: related to *ad-, verbum word, *verb]\n',
#  '\n',
#  'Adversary  n. (pl. -ies) enemy, opponent.\n',
#  '\n',
#  'Adverse  adj. Unfavourable; harmful. \x7f adversely adv. [latin: related to *ad-, verto vers- turn]\n',
#  '\n',
#  'Adversity  n. Misfortune, distress.\n',
#  '\n',
#  'Advert  n. Colloq. Advertisement. [abbreviation]\n',
#  '\n',
#  'Advertise  v. (-sing) 1 promote (goods or services) publicly to increase sales. 2 make generally known. 3 (often foll. By for) seek by a notice in a newspaper etc. To buy, employ, sell, etc. [french avertir: related to *adverse]\n',
#  '\n',
#  'Advertisement  n. 1 public announcement, esp. Of goods etc. For sale or wanted, vacancies, etc. 2 advertising. [french avertissement: related to *adverse]\n',
#  '\n',
#  'Advice  n. 1 recommendation on how to act. 2 information given; news. 3 formal notice of a transaction.\n',
#  '\n',
#  'Advisable  adj. To be recommended, expedient. \x7f advisability n.\n',
#  '\n',
#  'Advise  v. (-sing) 1 (also absol.) Give advice to. 2 recommend (advised me to rest). 3 (usu. Foll. By of, or that + clause) inform. [latin: related to *ad-, video vis- see]\n',
#  '\n',
#  'Advisedly  adv. After due consideration; deliberately.\n',
#  '\n',
#  'Adviser  n. (also advisor) person who advises, esp. Officially.\n',
#  '\n',
#  'Usage  the variant advisor is fairly common, but is considered incorrect by many people.\n',
#  '\n',
#  'Advisory  adj. Giving advice (advisory body).\n',
#  '\n',
#  'Advocaat  n. Liqueur of eggs, sugar, and brandy. [dutch, = *advocate]\n',
#  '\n',
#  'Advocacy  n. Support or argument for a cause, policy, etc.\n',
#  '\n',
#  'Advocate  —n. 1 (foll. By of) person who supports or speaks in favour. 2 person who pleads for another, esp. In a lawcourt. —v. (-ting) recommend by argument. [latin: related to *ad-, voco call]\n',
#  '\n',
#  'Adz  n. (brit adze) tool like an axe, with an arched blade at right angles to the handle. [old english]\n',
#  '\n',
#  'Adze  n. (us adz) tool like an axe, with an arched blade at right angles to the handle. [old english]\n',
#  '\n',
#  'Aegis  n. Protection; support. [greek aigis shield of zeus or athene]\n',
#  '\n',
#  'Aeolian harp  n. Stringed instrument or toy sounding when the wind passes through it. [latin aeolus wind-god, from greek]\n',
#  '\n',
#  'Aeon  n. (also eon) 1 long or indefinite period. 2 an age. [latin from greek]\n',
#  '\n',
#  'Aerate  v. (-ting) 1 charge (a liquid) with carbon dioxide. 2 expose to air. \x7f aeration n. [latin aer *air]\n',
#  '\n',
#  'Aerial  —n. Device for transmitting or receiving radio waves. —adj. 1 by or from the air; involving aircraft (aerial attack). 2 existing in the air. 3 of or like air. [greek: related to *air]\n',
#  '\n',
#  'Aero-  comb. Form air; aircraft. [greek aero- from aer air]\n',
#  '\n',
#  'Aerobatics  n.pl. 1 spectacular flying of aircraft, esp. To entertain. 2 (as sing.) Performance of these. [from *aero-, after *acrobatics]\n',
#  '\n',
#  'Aerobics  n.pl. Vigorous exercises designed to increase oxygen intake. \x7f aerobic adj. [from *aero-, greek bios life]\n',
#  '\n',
#  'Aerodrome  n. Small airport or airfield. [from *aero-, greek dromos course]\n',
#  '\n',
#  'Aerodynamics  n.pl. (usu. Treated as sing.) Dynamics of solid bodies moving through air. \x7f aerodynamic adj.\n',
#  '\n',
#  'Aerofoil  n. Structure with curved surfaces (e.g. A wing, fin, or tailplane) designed to give lift in flight.\n',
#  '\n',
#  'Aeronautics  n.pl. (usu. Treated as sing.) Science or practice of motion in the air. \x7f aeronautic adj. Aeronautical adj. [from *aero-, *nautical]\n',
#  '\n',
#  'Aeroplane  n. Powered heavier-than-air flying vehicle with fixed wings. [french: related to *aero-, *plane1]\n',
#  '\n',
#  'Aerosol  n. 1 pressurized container releasing a substance as a fine spray. 2 system of minute particles suspended in gas (e.g. Fog or smoke). [from *aero-, *solution]\n',
#  '\n',
#  "Aerospace  n. 1 earth's atmosphere and outer space. 2 aviation in this.\n",
#  '\n',
#  'Aesthete  n. Person who has or professes a special appreciation of beauty. [greek aisthanomai perceive]\n',
#  'Aesthete  n. Person who has or professes a special appreciation of beauty. [greek aisthanomai perceive]\n',
#  '\n',
#  'Aesthetic  —adj. 1 of or sensitive to beauty. 2 artistic, tasteful. —n. (in pl.) Philosophy of beauty, esp. In art. \x7f aesthetically adv. Aestheticism n.\n',
#  '\n',
#  'Aetiology  n. (us etiology) study of causation or of the causes of disease. \x7f aetiological adj. [greek aitia cause]\n',
#  '\n',
#  'Af  abbr. Audio frequency.\n',
#  '\n',
#  'Afar  adv. At or to a distance.\n',
#  '\n',
#  'Affable  adj. 1 friendly. 2 courteous. \x7f affability n. Affably adv. [latin affabilis]\n',
#  '\n',
#  'Affair  n. 1 matter, concern, or thing to be attended to (that is my affair). 2 a celebrated or notorious happening. B colloq. Thing or event (puzzling affair). 3 = *love affair. 4 (in pl.) Public or private business. [french à faire to do]\n',
#  '\n',
#  'Affect  v. 1 a produce an effect on. B (of disease etc.) Attack. 2 move emotionally. 3 pretend (affected ignorance). 4 pose as or use for effect (affects the aesthete; affects fancy hats). \x7f affecting adj. Affectingly adv. [latin afficio affect- influence]\n',
#  '\n',
#  'Usage  affect should not be confused with effect, meaning ‘to bring about’. Note also that effect is used as a noun as well as a verb.\n',
#  '\n',
#  'Affectation  n. 1 artificial manner. 2 (foll. By of) studied display. 3 pretence.\n',
#  '\n',
#  'Affected  adj. 1 pretended, artificial. 2 full of affectation.\n',
#  '\n',
#  'Affection  n. 1 goodwill, fond feeling. 2 disease; diseased condition.\n',
#  '\n',
#  'Affectionate  adj. Loving, fond. \x7f affectionately adv.\n',
#  '\n',
#  'Affidavit  n. Written statement confirmed by oath. [latin, = has stated on oath]\n',
#  '\n',
#  'Affiliate  —v. (-ting) (foll. By to, with) attach, adopt, or connect as a member or branch. —n. Affiliated person etc. [latin: related to *filial]\n',
#  '\n',
#  'Affiliation  n. Affiliating or being affiliated.\n',
#  '\n',
#  'Affiliation order  n. Legal order against the supposed father of an illegitimate child for support.\n',
#  '\n',
#  'Affinity  n. (pl. -ies) 1 liking or attraction; feeling of kinship. 2 relationship, esp. By marriage. 3 similarity of structure or character suggesting a relationship. 4 chem. The tendency of certain substances to combine with others. [latin finis border] \n',
#  '\n',
#  'Affirm  v. 1 assert, state as a fact. 2 law make a solemn declaration in place of an oath. \x7f affirmation n. [latin: related to *firm1]\n',
#  '\n',
#  'Affirmative  —adj. Affirming; expressing approval. —n. Affirmative statement or word etc.\n',
#  '\n',
#  'Affix  —v. 1 attach, fasten. 2 add in writing. —n. 1 addition. 2 gram. Prefix or suffix. [latin: related to *fix]\n',
#  '\n',
#  'Afflict  v. Distress physically or mentally. [latin fligo flict- strike down]\n',
#  '\n',
#  'Affliction  n. 1 distress, suffering. 2 cause of this.\n',
#  '\n',
#  'Affluent  adj. Wealthy, rich. \x7f affluence n. [latin: related to *fluent]\n',
#  '\n',
#  "Afford  v. 1 (prec. By can or be able to) a have enough money, time, etc., for; be able to spare. B be in a position (can't afford to be critical). 2 provide (affords a view of the sea). [old english ge- prefix implying completeness, *forth]\n",
#  '\n',
#  'Afforest  v. 1 convert into forest. 2 plant with trees. \x7f afforestation n. [latin: related to *forest]\n',
#  '\n',
#  'Affray  n. Breach of the peace by fighting or rioting in public. [anglo-french = ‘remove from peace’]\n',
#  '\n',
#  'Affront  —n. Open insult. —v. Insult openly; offend, embarrass. [latin: related to *front]\n',
#  '\n',
#  'Afghan  —n. 1 a native or national of afghanistan. B person of afghan descent. 2 official language of afghanistan. —adj. Of afghanistan. [pashto]\n',
#  '\n',
#  'Afghan hound  n. Tall hunting dog with long silky hair.\n',
#  '\n',
#  'Aficionado  n. (pl. -s) devotee of a sport or pastime. [spanish]\n',
#  '\n',
#  'Afield  adv. To or at a distance (esp. Far afield). [old english: related to *a2]\n',
#  '\n',
#  'Aflame  adv. & predic.adj. 1 in flames. 2 very excited.\n',
#  '\n',
#  'Afloat  adv. & predic.adj. 1 floating. 2 at sea. 3 out of debt or difficulty. 4 current. [old english: related to *a2]\n',
#  '\n',
#  'Afoot  adv. & predic.adj. In operation; progressing.\n',
#  '\n',
#  'Afore  prep. & adv. Archaic before; previously; in front (of). [old english: related to *a2]\n',
#  '\n',
#  'Afore-  comb. Form before, previously (aforementioned; aforesaid).\n',
#  'Afore  prep. & adv. Archaic before; previously; in front (of). [old english: related to *a2]\n',
#  '\n',
#  'Afore-  comb. Form before, previously (aforementioned; aforesaid).\n',
#  '\n',
#  'Aforethought  adj. Premeditated (following a noun: malice aforethought).\n',
#  '\n',
#  "Afraid  predic. Adj. Alarmed, frightened. \x7f be afraid colloq. Politely regret (i'm afraid we're late). [originally past part. Of *affray]\n",
#  '\n',
#  'Afresh  adv. Anew; with a fresh beginning. [earlier of fresh]\n',
#  '\n',
#  'African  —n. 1 native (esp. Dark-skinned) of africa. 2 person of african descent. —adj. Of africa. [latin]\n',
#  '\n',
#  'African elephant  n. The elephant of africa, larger than that of india.\n',
#  '\n',
#  'African violet  n. House-plant with velvety leaves and blue, purple, or pink flowers.\n',
#  '\n',
#  'Afrikaans  n. Language derived from dutch, used in s. Africa. [dutch, = ‘african’]\n',
#  '\n',
#  'Afrikaner  n. Afrikaans-speaking white person in s. Africa, esp. Of dutch descent.\n',
#  '\n',
#  'Afro  —adj. (of hair) tightly-curled and bushy. —n. (pl. -s) afro hairstyle.\n',
#  '\n',
#  'Afro-  comb. Form african.\n',
#  '\n',
#  'Afro-american  —adj. Of american blacks or their culture. —n. American black.\n',
#  '\n',
#  'Afro-caribbean  —n. Caribbean person of african descent. —adj. Of afro-caribbeans.\n',
#  '\n',
#  'Aft  adv. Naut. & aeron. At or towards the stern or tail. [earlier baft]\n',
#  '\n',
#  "After  —prep. 1 following in time; later than (after a week). 2 in view of, in spite of (after what you did what do you expect?; after all my efforts i still lost). 3 behind (shut the door after you). 4 in pursuit or quest of (run after them). 5 about, concerning (asked after her). 6 in allusion to (named after the prince). 7 in imitation of (a painting after rubens). 8 next in importance to (best one after mine). —conj. Later than (left after they arrived). —adv. 1 later (soon after). 2 behind (followed on after). —adj. 1 later, following (in after years). 2 naut. Nearer the stern (after cabins). \x7f after all in spite of everything (after all, what does it matter?). After one's own heart to one's taste. [old english]\n",
#  '\n',
#  'Afterbirth  n. Placenta etc. Discharged from the womb after childbirth.\n',
#  '\n',
#  'After-care  n. Attention after leaving hospital etc.\n',
#  '\n',
#  'After-effect  n. Delayed effect following an accident, trauma, etc.\n',
#  '\n',
#  'Afterglow  n. Glow remaining after its source has disappeared.\n',
#  '\n',
#  'Afterlife  n. Life after death.\n',
#  '\n',
#  'Aftermath  n. 1 consequences, esp. Unpleasant (aftermath of war). 2 new grass growing after mowing. [from *after, math mowing]\n',
#  '\n',
#  'Afternoon  n. Time from noon or lunch-time to evening.\n',
#  '\n',
#  'Afterpains  n.pl. Pains caused by contraction of the womb after childbirth.\n',
#  '\n',
#  'Afters  n.pl. Colloq. = *dessert 1.\n',
#  '\n',
#  'Aftershave  n. Lotion used after shaving.\n',
#  '\n',
#  'Aftertaste  n. Taste after eating or drinking.\n',
#  '\n',
#  'Afterthought  n. Thing thought of or added later.\n',
#  '\n',
#  'Afterward  adv. (brit. Afterwards) later, subsequently. [old english: related to *after, *-ward]\n',
#  '\n',
#  'Afterwards  adv. (us afterward) later, subsequently. [old english: related to *after, *-ward]\n',
#  ...]

# %%
#labeling words
labeled_words = list()
pos=0 # assuming the word is located only at 0
label=''
for sentence in dictionary:
    words = nltk.word_tokenize(sentence)
    if len(words)>2:
        pos = 0
        got_label = False
        while not got_label and pos<3:
            if words[pos+1].lower() in '-n.':
                label = 'noun'
                got_label = True
            elif words[pos+1].lower() in '-v.':
                label = 'verb'
                got_label = True
            elif words[pos+1].lower() in '-adj.':
                label = 'adjective'
                got_label = True
            elif words[pos+1].lower() in '-adv.':
                label = 'adverb'
                got_label = True
            else:
                got_label = False
                pos+=1
        labeled_words.append((words[0],label))
        print('*',end='')
# Out:
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# **************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************** ...
# ************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************************

# %%
labeled_words
# Out:
# [('A-', ''),
#  ('Aa', 'noun'),
#  ('Aardvark', 'noun'),
#  ('Ab-', 'noun'),
#  ('Aback', 'adverb'),
#  ('Abacus', 'noun'),
#  ('Abaft', 'noun'),
#  ('Abandon', 'noun'),
#  ('Abandoned', 'adjective'),
#  ('Abase', 'verb'),
#  ('Abashed', 'noun'),
#  ('Abate', 'verb'),
#  ('Abattoir', 'noun'),
#  ('Abbacy', 'noun'),
#  ('Abbé', 'noun'),
#  ('Abbess', 'noun'),
#  ('Abbey', 'noun'),
#  ('Abbot', 'noun'),
#  ('Abbreviate', 'verb'),
#  ('Abc', 'noun'),
#  ('Abdicate', 'verb'),
#  ('Abdomen', 'noun'),
#  ('Abduct', 'verb'),
#  ('Abeam', 'adverb'),
#  ('Aberdeen', 'noun'),
#  ('Aberdonian', 'noun'),
#  ('Aberrant', 'adjective'),
#  ('Aberration', 'noun'),
#  ('Abet', 'verb'),
#  ('Abeyance', 'noun'),
#  ('Abhor', 'verb'),
#  ('Abhorrence', 'noun'),
#  ('Abhorrent', 'adjective'),
#  ('Abide', 'verb'),
#  ('Abiding', 'adjective'),
#  ('Ability', 'noun'),
#  ('-ability', 'noun'),
#  ('Ab', 'adverb'),
#  ('Abject', 'adjective'),
#  ('Abjure', 'verb'),
#  ('Ablative', 'noun'),
#  ('Ablaze', 'noun'),
#  ('Able', 'adjective'),
#  ('-able', 'adjective'),
#  ('Able-bodied', 'adjective'),
#  ('Able-bodied', 'noun'),
#  ('Ablution', 'noun'),
#  ('-ably', 'noun'),
#  ('Abm', 'noun'),
#  ('Abnegate', 'verb'),
#  ('Abnegation', 'noun'),
#  ('Abnormal', 'adjective'),
#  ('Abo', 'adjective'),
#  ('Aboard', 'adverb'),
#  ('Abode1', 'noun'),
#  ('Abode2', 'noun'),
#  ('Abolish', 'verb'),
#  ('Abolition', 'noun'),
#  ('A-bomb', 'noun'),
#  ('Abominable', 'adjective'),
#  ('Abominable', 'noun'),
#  ('Abominate', 'verb'),
#  ('Aboriginal', 'noun'),
#  ('Aborigine', 'noun'),
#  ('Usage', 'noun'),
#  ('Abort', 'verb'),
#  ('Abortion', 'noun'),
#  ('Aboriginal', 'noun'),
#  ('Aborigine', 'noun'),
#  ('Usage', 'noun'),
#  ('Abort', 'verb'),
#  ('Abortion', 'noun'),
#  ('Abortive', 'adjective'),
#  ('Abound', 'verb'),
#  ('About', 'noun'),
#  ('About-face', 'noun'),
#  ('About-turn', 'noun'),
#  ('Above', 'noun'),
#  ('Above-board', 'adjective'),
#  ('Abracadabra', 'noun'),
#  ('Abrade', 'verb'),
#  ('Abrasion', 'noun'),
#  ('Abrasive', 'noun'),
#  ('Abreast', 'adverb'),
#  ('Abridge', 'verb'),
#  ('Abroad', 'adverb'),
#  ('Abrogate', 'verb'),
#  ('Abrupt', 'adjective'),
#  ('Abscess', 'noun'),
#  ('Abseil', 'noun'),
#  ('Absence', 'noun'),
#  ('Absent', 'noun'),
#  ('Absentee', 'noun'),
#  ('Absenteeism', 'noun'),
#  ('Absentee', 'noun'),
#  ('Absent-minded', 'adjective'),
#  ('Absinth', 'noun'),
#  ('Absolute', 'noun'),
#  ('Absolutely', 'adverb'),
#  ('Absolute', 'noun'),
#  ('Absolute', 'noun'),
#  ('Absolute', 'noun'),
#  ('Absolute', 'noun'),
#  ('Absolution', 'noun'),
#  ('Absolutism', 'noun'),
#  ('Absolve', 'verb'),
#  ('Absorb', 'verb'),
#  ('Absorbent', 'noun'),
#  ('Absorption', 'noun'),
#  ('Abstain', 'verb'),
#  ('Abstemious', 'adjective'),
#  ('Abstention', 'noun'),
#  ('Abstinence', 'noun'),
#  ('Abstract', 'noun'),
#  ('Abstracted', 'adjective'),
#  ('Abstraction', 'noun'),
#  ('Abstruse', 'adjective'),
#  ('Absurd', 'adjective'),
#  ('Abta', 'noun'),
#  ('Abundance', 'noun'),
#  ('Abundance', 'noun'),
#  ('Abundant', 'adjective'),
#  ('Abuse', 'noun'),
#  ('Abusive', 'adjective'),
#  ('Abut', 'verb'),
#  ('Abutment', 'noun'),
#  ('Abuzz', 'adverb'),
#  ('Abysmal', 'adjective'),
#  ('Abyss', 'noun'),
#  ('Ac', 'noun'),
#  ('Ac', 'noun'),
#  ('A/c', 'noun'),
#  ('-ac', 'noun'),
#  ('Acacia', 'noun'),
#  ('Academia', 'noun'),
#  ('Academic', 'noun'),
#  ('Academician', 'noun'),
#  ('Academy', 'noun'),
#  ('Acanthus', 'noun'),
#  ('A', 'adjective'),
#  ('Acas', 'noun'),
#  ('Accede', 'verb'),
#  ('Accelerate', 'verb'),
#  ('Accelerator', 'noun'),
#  ('Accent', 'noun'),
#  ('Accentuate', 'verb'),
#  ('Accept', 'verb'),
#  ('Acceptable', 'adjective'),
#  ('Acceptance', 'noun'),
#  ('Access', 'noun'),
#  ('Accessible', 'adjective'),
#  ('Accession', 'noun'),
#  ('Accessory', 'noun'),
#  ('Access', 'noun'),
#  ('Access', 'noun'),
#  ('Accident', 'noun'),
#  ('Accidental', 'noun'),
#  ('Accident-prone', 'adjective'),
#  ('Acclaim', 'noun'),
#  ('Acclamation', 'noun'),
#  ('Acclimatize', 'verb'),
#  ('Accolade', 'noun'),
#  ('Accommodate', 'verb'),
#  ('Accommodating', 'adjective'),
#  ('Accommodation', 'noun'),
#  ('Accommodation', 'noun'),
#  ('Accompaniment', 'noun'),
#  ('Accompany', 'verb'),
#  ('Accomplice', 'noun'),
#  ('Accomplish', 'verb'),
#  ('Accomplished', 'adjective'),
#  ('Accomplishment', 'noun'),
#  ('Accord', 'noun'),
#  ('Accordance', 'noun'),
#  ('According', 'adverb'),
#  ('Accordingly', 'adverb'),
#  ('Accordion', 'noun'),
#  ('Accost', 'verb'),
#  ('Accession', 'noun'),
#  ('Accessory', 'noun'),
#  ('Access', 'noun'),
#  ('Access', 'noun'),
#  ('Accident', 'noun'),
#  ('Accidental', 'noun'),
#  ('Accident-prone', 'adjective'),
#  ('Acclaim', 'noun'),
#  ('Acclamation', 'noun'),
#  ('Acclimatize', 'verb'),
#  ('Accolade', 'noun'),
#  ('Accommodate', 'verb'),
#  ('Accommodating', 'adjective'),
#  ('Accommodation', 'noun'),
#  ('Accommodation', 'noun'),
#  ('Accompaniment', 'noun'),
#  ('Accompany', 'verb'),
#  ('Accomplice', 'noun'),
#  ('Accomplish', 'verb'),
#  ('Accomplished', 'adjective'),
#  ('Accomplishment', 'noun'),
#  ('Accord', 'noun'),
#  ('Accordance', 'noun'),
#  ('According', 'adverb'),
#  ('Accordingly', 'adverb'),
#  ('Accordion', 'noun'),
#  ('Accost', 'verb'),
#  ('Account', 'noun'),
#  ('Accountable', 'adjective'),
#  ('Accountant', 'noun'),
#  ('Accouterments', 'noun'),
#  ('Accoutrements', 'noun'),
#  ('Accredit', 'verb'),
#  ('Accredited', 'adjective'),
#  ('Accretion', 'noun'),
#  ('Accrue', 'verb'),
#  ('Accumulate', 'verb'),
#  ('Accumulation', 'noun'),
#  ('Accumulator', 'noun'),
#  ('Accuracy', 'noun'),
#  ('Accurate', 'adjective'),
#  ('Accursed', 'adjective'),
#  ('Accusation', 'noun'),
#  ('Accusative', 'noun'),
#  ('Accusatory', 'adjective'),
#  ('Accuse', 'verb'),
#  ('Accustom', 'verb'),
#  ('Accustomed', 'adjective'),
#  ('Ace', 'noun'),
#  ('Acellular', 'adjective'),
#  ('Aceous', 'adjective'),
#  ('Acerbic', 'adjective'),
#  ('Acetaldehyde', 'noun'),
#  ('Acetate', 'noun'),
#  ('Acetic', 'adjective'),
#  ('Acetic', 'noun'),
#  ('Acetone', 'noun'),
#  ('Acetylene', 'noun'),
#  ('Ache', 'noun'),
#  ('Achieve', 'verb'),
#  ('Achievement', 'noun'),
#  ('Achilles', 'noun'),
#  ('Achilles', 'noun'),
#  ('Achromatic', 'adjective'),
#  ('Achy', 'adjective'),
#  ('Acid', 'noun'),
#  ('Acid', 'noun'),
#  ('Acid', 'noun'),
#  ('Acid', 'noun'),
#  ('Acidulous', 'adjective'),
#  ('Ack-ack', 'noun'),
#  ('Acknowledge', 'verb'),
#  ('Acknowledgement', 'noun'),
#  ('Acme', 'noun'),
#  ('Acne', 'noun'),
#  ('Acolyte', 'noun'),
#  ('Aconite', 'noun'),
#  ('Acorn', 'noun'),
#  ('Acoustic', 'adjective'),
#  ('Acoustics', 'noun'),
#  ('Acquaint', 'verb'),
#  ('Acquaintance', 'noun'),
#  ('Acquiesce', 'verb'),
#  ('Acquire', 'verb'),
#  ('Acquired', 'verb'),
#  ('Acquired', 'noun'),
#  ('Acquirement', 'noun'),
#  ('Acquisition', 'noun'),
#  ('Acquisitive', 'adjective'),
#  ('Acquit', 'verb'),
#  ('Acre', 'noun'),
#  ('Acreage', 'noun'),
#  ('Acrid', 'adjective'),
#  ('Acrimonious', 'adjective'),
#  ('Acrobat', 'noun'),
#  ('Acrobatics', 'noun'),
#  ('Acronym', 'noun'),
#  ('Acropolis', 'noun'),
#  ('Across', 'noun'),
#  ('Acrostic', 'noun'),
#  ('Acrylic', 'noun'),
#  ('Acrylic', 'noun'),
#  ('Act', 'noun'),
#  ('Acting', 'noun'),
#  ('Actinism', 'noun'),
#  ('Actinium', 'noun'),
#  ('Action', 'noun'),
#  ('Actionable', 'adjective'),
#  ('Action-packed', 'adjective'),
#  ('Action', 'noun'),
#  ('Action', 'noun'),
#  ('Action', 'noun'),
#  ('Activate', 'verb'),
#  ('Active', 'noun'),
#  ('Active', 'noun'),
#  ('Activism', 'noun'),
#  ('Activity', 'noun'),
#  ('Actor', 'noun'),
#  ('Actress', 'noun'),
#  ('Actual', 'adjective'),
#  ('Actuality', 'noun'),
#  ('Actually', 'adverb'),
#  ('Actuary', 'noun'),
#  ('Actuate', 'verb'),
#  ('Acuity', 'noun'),
#  ('Acumen', 'noun'),
#  ('Acupuncture', 'noun'),
#  ('Acute', 'noun'),
#  ('Acute', 'noun'),
#  ('-acy', 'noun'),
#  ('Ad', 'noun'),
#  ('Ad', 'noun'),
#  ('Ad-', 'noun'),
#  ('Adage', 'noun'),
#  ('Adagio', 'noun'),
#  ('Adam', 'noun'),
#  ('Adamant', 'adjective'),
#  ('Adam', 'noun'),
#  ('Adapt', 'verb'),
#  ('Adaptor', 'noun'),
#  ('Add', 'verb'),
#  ('Addendum', 'noun'),
#  ('Adder', 'noun'),
#  ('Addict', 'noun'),
#  ('Addicted', 'adjective'),
#  ('Addictive', 'adjective'),
#  ('Addition', 'noun'),
#  ('Additional', 'adjective'),
#  ('Additive', 'noun'),
#  ('Addle', 'verb'),
#  ('Address', 'noun'),
#  ('Addressee', 'noun'),
#  ('Adduce', 'verb'),
#  ('Adenoids', 'noun'),
#  ('Adept', 'noun'),
#  ('Adequate', 'adjective'),
#  ('À', 'adverb'),
#  ('Adhere', 'verb'),
#  ('Adherent', 'noun'),
#  ('Adhesion', 'noun'),
#  ('Adhesive', 'noun'),
#  ('Ad', 'adverb'),
#  ('Adieu', 'noun'),
#  ('Ad', 'adverb'),
#  ('Adipose', 'adjective'),
#  ('Adjacent', 'adjective'),
#  ('Adjective', 'noun'),
#  ('Adjoin', 'verb'),
#  ('Adjourn', 'verb'),
#  ('Adjudge', 'verb'),
#  ('Adjudicate', 'verb'),
#  ('Adjunct', 'noun'),
#  ('Adjure', 'verb'),
#  ('Adjust', 'verb'),
#  ('Adjutant', 'noun'),
#  ('Ad', 'noun'),
#  ('Admin', 'noun'),
#  ('Administer', 'verb'),
#  ('Administrate', 'verb'),
#  ('Administration', 'noun'),
#  ('Administrative', 'adjective'),
#  ('Administrator', 'noun'),
#  ('Admirable', 'adjective'),
#  ('Admiral', 'noun'),
#  ('Admiralty', 'noun'),
#  ('Admiration', 'noun'),
#  ('Admire', 'verb'),
#  ('Admissible', 'adjective'),
#  ('Admission', 'noun'),
#  ('Admit', 'verb'),
#  ('Admittance', 'noun'),
#  ('Admittedly', 'adverb'),
#  ('Admixture', 'noun'),
#  ('Admonish', 'verb'),
#  ('Ad', 'adverb'),
#  ('Ado', 'noun'),
#  ('Adobe', 'noun'),
#  ('Adolescent', 'noun'),
#  ('Adonis', 'noun'),
#  ('Adopt', 'verb'),
#  ('Adoptive', 'adjective'),
#  ('Adorable', 'adjective'),
#  ('Adore', 'verb'),
#  ('Adorn', 'verb'),
#  ('Adrenal', 'noun'),
#  ('Adrenalin', 'noun'),
#  ('Adrift', 'adverb'),
#  ('Adroit', 'adjective'),
#  ('Adsorb', 'verb'),
#  ('Adulation', 'noun'),
#  ('Adult', 'noun'),
#  ('Adulterate', 'verb'),
#  ('Adulterer', 'noun'),
#  ('Adultery', 'noun'),
#  ('Adumbrate', 'verb'),
#  ('Advance', 'noun'),
#  ('Advanced', 'noun'),
#  ('Advancement', 'noun'),
#  ('Advantage', 'noun'),
#  ('Advent', 'noun'),
#  ('Adventist', 'noun'),
#  ('Adventitious', 'adjective'),
#  ('Adventure', 'noun'),
#  ('Adventure', 'noun'),
#  ('Adventurer', 'noun'),
#  ('Adventurous', 'adjective'),
#  ('Adverb', 'noun'),
#  ('Adversary', 'noun'),
#  ('Adverse', 'adjective'),
#  ('Adversity', 'noun'),
#  ('Advert', 'noun'),
#  ('Advertise', 'verb'),
#  ('Advertisement', 'noun'),
#  ('Advice', 'noun'),
#  ('Advisable', 'adjective'),
#  ('Advise', 'verb'),
#  ('Advisedly', 'adverb'),
#  ('Adviser', 'noun'),
#  ('Usage', 'noun'),
#  ('Advisory', 'adjective'),
#  ('Advocaat', 'noun'),
#  ('Advocacy', 'noun'),
#  ('Advocate', 'noun'),
#  ('Adz', 'noun'),
#  ('Adze', 'noun'),
#  ('Aegis', 'noun'),
#  ('Aeolian', 'noun'),
#  ('Aeon', 'noun'),
#  ('Aerate', 'verb'),
#  ('Aerial', 'noun'),
#  ('Aero-', 'noun'),
#  ('Aerobatics', 'noun'),
#  ('Aerobics', 'noun'),
#  ('Aerodrome', 'noun'),
#  ('Aerodynamics', 'noun'),
#  ('Aerofoil', 'noun'),
#  ('Aeronautics', 'noun'),
#  ('Aeroplane', 'noun'),
#  ('Aerosol', 'noun'),
#  ('Aerospace', 'noun'),
#  ('Aesthete', 'noun'),
#  ('Aesthete', 'noun'),
#  ('Aesthetic', 'noun'),
#  ('Aetiology', 'noun'),
#  ('Af', 'noun'),
#  ('Afar', 'adverb'),
#  ('Affable', 'adjective'),
#  ('Affair', 'noun'),
#  ('Affect', 'verb'),
#  ('Usage', 'verb'),
#  ('Affectation', 'noun'),
#  ('Affected', 'adjective'),
#  ('Affection', 'noun'),
#  ('Affectionate', 'adjective'),
#  ('Affidavit', 'noun'),
#  ('Affiliate', 'noun'),
#  ('Affiliation', 'noun'),
#  ('Affiliation', 'noun'),
#  ('Affinity', 'noun'),
#  ('Affirm', 'verb'),
#  ('Affirmative', 'noun'),
#  ('Affix', 'noun'),
#  ('Afflict', 'verb'),
#  ('Affliction', 'noun'),
#  ('Affluent', 'adjective'),
#  ('Afford', 'verb'),
#  ('Afforest', 'verb'),
#  ('Affray', 'noun'),
#  ('Affront', 'noun'),
#  ('Afghan', 'noun'),
#  ('Afghan', 'noun'),
#  ('Aficionado', 'noun'),
#  ('Afield', 'adverb'),
#  ('Aflame', 'adverb'),
#  ('Afloat', 'adverb'),
#  ('Afoot', 'adverb'),
#  ('Afore', 'noun'),
#  ('Afore-', 'noun'),
#  ('Afore', 'noun'),
#  ('Afore-', 'noun'),
#  ('Aforethought', 'adjective'),
#  ('Afraid', 'noun'),
#  ('Afresh', 'adverb'),
#  ('African', 'noun'),
#  ('African', 'noun'),
#  ('African', 'noun'),
#  ('Afrikaans', 'noun'),
#  ('Afrikaner', 'noun'),
#  ('Afro', 'noun'),
#  ('Afro-', 'noun'),
#  ('Afro-american', 'noun'),
#  ('Afro-caribbean', 'noun'),
#  ('Aft', 'adverb'),
#  ('After', 'noun'),
#  ('Afterbirth', 'noun'),
#  ('After-care', 'noun'),
#  ('After-effect', 'noun'),
#  ('Afterglow', 'noun'),
#  ('Afterlife', 'noun'),
#  ('Aftermath', 'noun'),
#  ('Afternoon', 'noun'),
#  ('Afterpains', 'noun'),
#  ('Afters', 'noun'),
#  ('Aftershave', 'noun'),
#  ('Aftertaste', 'noun'),
#  ('Afterthought', 'noun'),
#  ('Afterward', 'adverb'),
#  ('Afterwards', 'adverb'),
#  ('Ag', 'noun'),
#  ('Again', 'adverb'),
#  ('Against', 'noun'),
#  ('Agape', 'noun'),
#  ('Agaric', 'noun'),
#  ('Agate', 'noun'),
#  ('Agate', 'noun'),
#  ('Agave', 'noun'),
#  ('Age', 'noun'),
#  ('-age', 'noun'),
#  ('Aged', 'adjective'),
#  ('Ageism', 'noun'),
#  ('Ageless', 'adjective'),
#  ('Agelong', 'adjective'),
#  ('Agency', 'noun'),
#  ('Agenda', 'noun'),
#  ('Agent', 'noun'),
#  ('Agent', 'noun'),
#  ('Age', 'noun'),
#  ('Age-old', 'adjective'),
#  ('Agglomerate', 'noun'),
#  ('Agglutinate', 'verb'),
#  ('Aggrandize', 'verb'),
#  ('Aggravate', 'verb'),
#  ('Usage', 'verb'),
#  ('Aggregate', 'noun'),
#  ('Aggression', 'noun'),
#  ('Aggressive', 'adjective'),
#  ('Aggressor', 'noun'),
#  ('Aggrieved', 'adjective'),
#  ('Aggro', 'noun'),
#  ('Aghast', 'noun'),
#  ('Agile', 'adjective'),
#  ('Agitate', 'verb'),
#  ('Aglow', 'noun'),
#  ('Agm', 'noun'),
#  ('Agnail', 'noun'),
#  ('Agnostic', 'noun'),
#  ('Ago', 'adverb'),
#  ('Agog', 'noun'),
#  ('Agonize', 'verb'),
#  ('Agony', 'noun'),
#  ('Agony', 'noun'),
#  ('Agony', 'noun'),
#  ('Agoraphobia', 'noun'),
#  ('Agrarian', 'noun'),
#  ('Agree', 'verb'),
#  ('Agreeable', 'adjective'),
#  ('Agreement', 'noun'),
#  ('Agriculture', 'noun'),
#  ('Agrimony', 'noun'),
#  ('Agronomy', 'noun'),
#  ('Aground', 'noun'),
#  ('Ague', 'noun'),
#  ('Ah', 'noun'),
#  ('Ah', 'noun'),
#  ('Aha', 'noun'),
#  ('Ahead', 'adverb'),
#  ('Ahem', 'noun'),
#  ('Ahoy', 'noun'),
#  ('Ai', 'noun'),
#  ('Aid', 'noun'),
#  ('Aid', 'noun'),
#  ('Aide', 'noun'),
#  ('Aide-de-camp', 'noun'),
#  ('Aids', 'noun'),
#  ('Ail', 'verb'),
#  ('Aileron', 'noun'),
#  ('Ailing', 'adjective'),
#  ('Ailment', 'noun'),
#  ('Aim', 'noun'),
#  ('Aimless', 'adjective'),
#  ('Ai', 'noun'),
#  ('Usage', 'noun'),
#  ('Aimless', 'adjective'),
#  ('Ai', 'noun'),
#  ('Usage', 'noun'),
#  ('Air', 'noun'),
#  ('Airbase', 'noun'),
#  ('Air-bed', 'noun'),
#  ('Airborne', 'adjective'),
#  ('Air-brick', 'noun'),
#  ('Airbus', 'noun'),
#  ('Air', 'noun'),
#  ('Air', 'noun'),
#  ('Air-conditioning', 'noun'),
#  ('Aircraft', 'noun'),
#  ('Aircraft-carrier', 'noun'),
#  ('Aircraftman', 'noun'),
#  ('Aircraftwoman', 'noun'),
#  ('Aircrew', 'noun'),
#  ('Air-cushion', 'noun'),
#  ('Airedale', 'noun'),
#  ('Airer', 'noun'),
#  ('Airfield', 'noun'),
#  ('Air', 'noun'),
#  ('Airgun', 'noun'),
#  ('Airhead', 'noun'),
#  ('Air', 'noun'),
#  ('Airless', 'adjective'),
#  ('Air', 'noun'),
#  ('Airlift', 'noun'),
#  ('Airline', 'noun'),
#  ('Airliner', 'noun'),
#  ('Airlock', 'noun'),
#  ('Airmail', 'noun'),
#  ('Airman', 'noun'),
#  ('Air', 'noun'),
#  ('Airplane', 'noun'),
#  ('Air', 'noun'),
#  ('Airport', 'noun'),
#  ('Air', 'noun'),
#  ('Air', 'noun'),
#  ('Airs', 'noun'),
#  ('Airscrew', 'noun'),
#  ('Airship', 'noun'),
#  ('Airsick', 'adjective'),
#  ('Airspace', 'noun'),
#  ('Air', 'noun'),
#  ('Airstrip', 'noun'),
#  ('Air', 'noun'),
#  ('Airtight', 'adjective'),
#  ('Air', 'noun'),
#  ('Air', 'noun'),
#  ('Airwaves', 'noun'),
#  ('Airway', 'noun'),
#  ('Airwoman', 'noun'),
#  ('Airworthy', 'adjective'),
#  ('Airy', 'adjective'),
#  ('Airy-fairy', 'adjective'),
#  ('Aisle', 'noun'),
#  ('Aitch', 'noun'),
#  ('Aitchbone', 'noun'),
#  ('Ajar', 'adverb'),
#  ('Akela', 'noun'),
#  ('Akimbo', 'adverb'),
#  ('Akin', 'noun'),
#  ('Al', 'noun'),
#  ('-al', 'noun'),
#  ('À', 'noun'),
#  ('Alabaster', 'noun'),
#  ('À', 'adverb'),
#  ('Alacrity', 'noun'),
#  ('À', 'adverb'),
#  ('Alarm', 'noun'),
#  ('Alarm', 'noun'),
#  ('Alarmist', 'noun'),
#  ('Alas', 'noun'),
#  ('Alb', 'noun'),
#  ('Albatross', 'noun'),
#  ('Albeit', 'noun'),
#  ('Albino', 'noun'),
#  ('Album', 'noun'),
#  ('Albumen', 'noun'),
#  ('Albumin', 'noun'),
#  ('Alchemy', 'noun'),
#  ('Alcohol', 'noun'),
#  ('Alcoholic', 'noun'),
#  ('Alcoholism', 'noun'),
#  ('Alcove', 'noun'),
#  ('Aldehyde', 'noun'),
#  ('Aldehyde', 'noun'),
#  ('Al', 'adjective'),
#  ('Alder', 'noun'),
#  ('Alderman', 'noun'),
#  ('Ale', 'noun'),
#  ('Aleatory', 'adjective'),
#  ('Alehouse', 'noun'),
#  ('Alembic', 'noun'),
#  ('Alert', 'noun'),
#  ('A', 'noun'),
#  ('Alexander', 'noun'),
#  ('Alexandrine', 'noun'),
#  ('Alfalfa', 'noun'),
#  ('Alfresco', 'adverb'),
#  ('Alga', 'noun'),
#  ('Algebra', 'noun'),
#  ('Algol', 'noun'),
#  ('Algorithm', 'noun'),
#  ('Alias', 'noun'),
#  ('Alibi', 'noun'),
#  ('Usage', 'noun'),
#  ('Alien', 'noun'),
#  ('Alienable', 'adjective'),
#  ('Alienate', 'verb'),
#  ('Alight1', 'noun'),
#  ('Alight2', 'verb'),
#  ('Align', 'verb'),
#  ('Alike', 'noun'),
#  ('Alimentary', 'adjective'),
#  ('Alimentary', 'noun'),
#  ('Alimony', 'noun'),
#  ('Usage', 'noun'),
#  ('Aliphatic', 'adjective'),
#  ('Aliquot', 'noun'),
#  ('Alive', 'adjective'),
#  ('Alkali', 'noun'),
#  ('Alkalinity', 'noun'),
#  ('Alkaloid', 'noun'),
#  ('Alkane', 'noun'),
#  ('Alkene', 'noun'),
#  ('Alkyne', 'noun'),
#  ('All', 'noun'),
#  ('Usage', 'noun'),
#  ('Allah', 'noun'),
#  ('Allay', 'verb'),
#  ('All-clear', 'noun'),
#  ('All', 'noun'),
#  ('Allegation', 'noun'),
#  ('Allege', 'verb'),
#  ('Allegedly', 'adverb'),
#  ('Allegiance', 'noun'),
#  ('Allegory', 'noun'),
#  ('Allegretto', 'noun'),
#  ('Allegro', 'noun'),
#  ('Alleluia', 'noun'),
#  ('Allen', 'noun'),
#  ('Allen', 'noun'),
#  ('Allergic', 'adjective'),
#  ('Allergy', 'noun'),
#  ('Alleviate', 'verb'),
#  ('Alley', 'noun'),
#  ('Alliance', 'noun'),
#  ('Allied', 'adjective'),
#  ('Alligator', 'noun'),
#  ('All-in', 'noun'),
#  ('All-in', 'noun'),
#  ('Alliteration', 'noun'),
#  ('Allocate', 'verb'),
#  ('Allot', 'verb'),
#  ('Allotment', 'noun'),
#  ('Allotropy', 'noun'),
#  ('Allow', 'verb'),
#  ('Allowance', 'noun'),
#  ('Alloy', 'noun'),
#  ('All-purpose', 'noun'),
#  ('All-right', 'noun'),
#  ('All-round', 'noun'),
#  ('All-rounder', 'noun'),
#  ('All', 'noun'),
#  ('All', 'noun'),
#  ('Allspice', 'noun'),
#  ('All-time', 'noun'),
#  ('Allude', 'verb'),
#  ('Allure', 'noun'),
#  ('Allusion', 'noun'),
#  ('Alluvial', 'noun'),
#  ('Alleluia', 'noun'),
#  ('Allen', 'noun'),
#  ('Allen', 'noun'),
#  ('Allergic', 'adjective'),
#  ('Allergy', 'noun'),
#  ('Alleviate', 'verb'),
#  ('Alley', 'noun'),
#  ('Alliance', 'noun'),
#  ('Allied', 'adjective'),
#  ('Alligator', 'noun'),
#  ('All-in', 'noun'),
#  ('All-in', 'noun'),
#  ('Alliteration', 'noun'),
#  ('Allocate', 'verb'),
#  ('Allot', 'verb'),
#  ('Allotment', 'noun'),
#  ('Allotropy', 'noun'),
#  ('Allow', 'verb'),
#  ('Allowance', 'noun'),
#  ('Alloy', 'noun'),
#  ('All-purpose', 'noun'),
#  ('All-right', 'noun'),
#  ('All-round', 'noun'),
#  ('All-rounder', 'noun'),
#  ('All', 'noun'),
#  ('All', 'noun'),
#  ('Allspice', 'noun'),
#  ('All-time', 'noun'),
#  ('Allude', 'verb'),
#  ('Allure', 'noun'),
#  ('Allusion', 'noun'),
#  ('Alluvial', 'noun'),
#  ('Alluvial', 'noun'),
#  ('Alluvium', 'noun'),
#  ('Ally', 'noun'),
#  ('Alma', 'noun'),
#  ('Almanac', 'noun'),
#  ('Almighty', 'adjective'),
#  ('Almond', 'noun'),
#  ('Almoner', 'noun'),
#  ('Usage', 'noun'),
#  ('Almost', 'adverb'),
#  ('Alms', 'noun'),
#  ('Almshouse', 'noun'),
#  ('Aloe', 'noun'),
#  ('Aloft', 'noun'),
#  ('Alone', 'noun'),
#  ('Along', 'noun'),
#  ('Alongside', 'noun'),
#  ('Aloof', 'noun'),
#  ('Aloud', 'adverb'),
#  ('Alp', 'noun'),
#  ('Alpaca', 'noun'),
#  ('Alpha', 'noun'),
#  ('Alphabet', 'noun'),
#  ('Alphanumeric', 'adjective'),
#  ('Alpha', 'noun'),
#  ('Alpine', 'noun'),
#  ('Already', 'adverb'),
#  ('Alright', 'adverb'),
#  ('Usage', 'adverb'),
#  ('Alsatian', 'noun'),
#  ('Also', 'adverb'),
#  ('Also-ran', 'noun'),
#  ('Altar', 'noun'),
#  ('Altarpiece', 'noun'),
#  ('Alter', 'verb'),
#  ('Altercate', 'verb'),
#  ('Alter', 'noun'),
#  ('Alter', 'noun'),
#  ('Alternate', 'noun'),
#  ('Usage', 'noun'),
#  ('Alternate', 'noun'),
#  ('Alternating', 'noun'),
#  ('Alternative', 'noun'),
#  ('Usage', 'noun'),
#  ('Alternator', 'noun'),
#  ('Although', 'noun'),
#  ('Altimeter', 'noun'),
#  ('Altitude', 'noun'),
#  ('Alto', 'noun'),
#  ('Altogether', 'adverb'),
#  ('Usage', 'adverb'),
#  ('Altruism', 'noun'),
#  ('Alum', 'noun'),
#  ('Alumina', 'noun'),
#  ('Aluminium', 'noun'),
#  ('Aluminize', 'verb'),
#  ('Aluminum', 'noun'),
#  ('Alumnus', 'noun'),
#  ('Always', 'adverb'),
#  ('Alyssum', 'noun'),
#  ('Alzheimer', 'noun'),
#  ('Am', 'noun'),
#  ('Am', 'noun'),
#  ('Am', 'noun'),
#  ('A.m.', 'noun'),
#  ('Amalgam', 'noun'),
#  ('Amalgamate', 'verb'),
#  ('Amanuensis', 'noun'),
#  ('Amaranth', 'noun'),
#  ('Amaryllis', 'noun'),
#  ('Amass', 'verb'),
#  ('Amateur', 'noun'),
#  ('Amatory', 'adjective'),
#  ('Amatory', 'adjective'),
#  ('Amaze', 'verb'),
#  ('Amazon', 'noun'),
#  ('Ambassador', 'noun'),
#  ('Amber', 'noun'),
#  ('Ambergris', 'noun'),
#  ('Ambidextrous', 'adjective'),
#  ('Ambience', 'noun'),
#  ('Ambient', 'adjective'),
#  ('Ambiguous', 'adjective'),
#  ('Ambit', 'noun'),
#  ('Ambition', 'noun'),
#  ('Ambitious', 'adjective'),
#  ('Ambivalence', 'noun'),
#  ('Amble', 'noun'),
#  ('Ambrosia', 'noun'),
#  ('Ambulance', 'noun'),
#  ('Ambulatory', 'noun'),
#  ('Ambuscade', 'noun'),
#  ('Ambush', 'noun'),
#  ('Ameliorate', 'verb'),
#  ('Amen', 'noun'),
#  ('Amenable', 'adjective'),
#  ('Amend', 'verb'),
#  ('Usage', 'verb'),
#  ('Amendment', 'noun'),
#  ('Amends', 'noun'),
#  ('Amenity', 'noun'),
#  ('American', 'noun'),
#  ('American', 'noun'),
#  ('American', 'noun'),
#  ('American', 'noun'),
#  ('Americanism', 'noun'),
#  ('Americium', 'noun'),
#  ('Amerind', 'adjective'),
#  ('Amethyst', 'noun'),
#  ('Amharic', 'noun'),
#  ('Amiable', 'adjective'),
#  ('Amiable', 'adjective'),
#  ('Amicable', 'adjective'),
#  ('Amid', 'noun'),
#  ('Amidships', 'adverb'),
#  ('Amidst', 'noun'),
#  ('Amine', 'noun'),
#  ('Amino', 'noun'),
#  ('Amir', 'noun'),
#  ('Amiss', 'noun'),
#  ('Amity', 'noun'),
#  ('Ammeter', 'noun'),
#  ('Ammo', 'noun'),
#  ('Ammonia', 'noun'),
#  ('Ammonite', 'noun'),
#  ('Ammunition', 'noun'),
#  ('Amnesia', 'noun'),
#  ('Amnesty', 'noun'),
#  ('Amniocentesis', 'noun'),
#  ('Amnion', 'noun'),
#  ('Amoeba', 'noun'),
#  ('Amok', 'adverb'),
#  ('Among', 'noun'),
#  ('Amoral', 'adjective'),
#  ('Amorous', 'adjective'),
#  ('Amorphous', 'adjective'),
#  ('Amortize', 'verb'),
#  ('Amount', 'noun'),
#  ('Amour', 'noun'),
#  ('Amour', 'noun'),
#  ('Amp1', 'noun'),
#  ('Amp2', 'noun'),
#  ('Ampelopsis', 'noun'),
#  ('Amperage', 'noun'),
#  ('Ampere', 'noun'),
#  ('Ampersand', 'noun'),
#  ('Amphetamine', 'noun'),
#  ('Amphibian', 'noun'),
#  ('Amphibious', 'adjective'),
#  ('Amphitheatre', 'noun'),
#  ('Amphitheatre', 'noun'),
#  ('Amphora', 'noun'),
#  ('Ample', 'adjective'),
#  ('Amplifier', 'noun'),
#  ('Amplify', 'verb'),
#  ('Amplitude', 'noun'),
#  ('Amplitude', 'noun'),
#  ('Ampoule', 'noun'),
#  ('Ampulla', 'noun'),
#  ('Amputate', 'verb'),
#  ('Amuck', 'noun'),
#  ('Amulet', 'noun'),
#  ('Amuse', 'verb'),
#  ('Amusement', 'noun'),
#  ('Amusement', 'noun'),
#  ('An', 'noun'),
#  ('An-', 'noun'),
#  ('-an', 'noun'),
#  ('Anabaptist', 'noun'),
#  ('Anabolic', 'noun'),
#  ('Anabolism', 'noun'),
#  ('Anachronism', 'noun'),
#  ('Anaconda', 'noun'),
#  ('Anaemia', 'noun'),
#  ('Anaemic', 'adjective'),
#  ('Anaesthesia', 'noun'),
#  ('Anaesthetic', 'noun'),
#  ('Anaesthetist', 'noun'),
#  ('Anaesthetize', 'verb'),
#  ('Anagram', 'noun'),
#  ('Anal', 'adjective'),
#  ('Analgesia', 'noun'),
#  ('Analgesic', 'noun'),
#  ('Analog', 'noun'),
#  ('Analogize', 'verb'),
#  ('Analogous', 'adjective'),
#  ('Analogue', 'noun'),
#  ('Analogy', 'noun'),
#  ('Analogy', 'noun'),
#  ('Analyse', 'verb'),
#  ('Analysis', 'noun'),
#  ('Analyst', 'noun'),
#  ('Analytical', 'adjective'),
#  ('Analyze', 'noun'),
#  ('Anapaest', 'noun'),
#  ('Anarchism', 'noun'),
#  ('Anarchist', 'noun'),
#  ('Anarchy', 'noun'),
#  ('Anathema', 'noun'),
#  ('Anathematize', 'verb'),
#  ('Anatomy', 'noun'),
#  ('Anatto', 'noun'),
#  ('Anc', 'noun'),
#  ('-ance', 'noun'),
#  ('Ancestor', 'noun'),
#  ('Ancestral', 'adjective'),
#  ('Ancestry', 'noun'),
#  ('Anchor', 'noun'),
#  ('Anchorage', 'noun'),
#  ('Anchorite', 'noun'),
#  ('Anchorman', 'noun'),
#  ('Anchovy', 'noun'),
#  ('Ancien', 'noun'),
#  ('Ancient', 'adjective'),
#  ('Ancillary', 'noun'),
#  ...]

# %%
import random

# %%
random.shuffle(labeled_words)

# %%
labeled_words
# Out:
# [('Troubleshooter', 'noun'),
#  ('Pps', 'noun'),
#  ('Reawaken', 'verb'),
#  ('Winceyette', 'noun'),
#  ('Bundle', 'noun'),
#  ('Slue', 'noun'),
#  ('Vanadium', 'noun'),
#  ('Deep-laid', 'adjective'),
#  ('Almost', 'adverb'),
#  ('Pinny', 'noun'),
#  ('Onerous', 'adjective'),
#  ('Snappy', 'adjective'),
#  ('Punch-drunk', 'adjective'),
#  ('Pothole', 'noun'),
#  ('En', 'noun'),
#  ('Apricot', 'noun'),
#  ('Legal', 'noun'),
#  ('Headword', 'noun'),
#  ('Pastel', 'noun'),
#  ('Torchlight', 'noun'),
#  ('Majority', 'noun'),
#  ('Culture', 'noun'),
#  ('Package', 'noun'),
#  ('Home', 'noun'),
#  ('Civilization', 'noun'),
#  ('Warbler', 'noun'),
#  ('Pathology', 'noun'),
#  ('Sharpshooter', 'noun'),
#  ('Brake', 'noun'),
#  ('Untwist', 'verb'),
#  ('Locality', 'noun'),
#  ('Hopper1', 'noun'),
#  ('Self-rule', 'noun'),
#  ('Running', 'noun'),
#  ('Struggle', 'noun'),
#  ('Cause', 'noun'),
#  ('Unsubstantiated', 'adjective'),
#  ('Pity', 'noun'),
#  ('Idolize', 'verb'),
#  ('Public', 'noun'),
#  ('Chunk', 'noun'),
#  ('Gangling', 'adjective'),
#  ('Pentagram', 'noun'),
#  ('Hear', 'verb'),
#  ('Refulgent', 'adjective'),
#  ('Horrify', 'verb'),
#  ('Turbot', 'noun'),
#  ('Battlebus', 'noun'),
#  ('Tuffet', 'noun'),
#  ('Hair', 'noun'),
#  ('Vapour', 'noun'),
#  ('Inexpert', 'adjective'),
#  ('Set', 'noun'),
#  ('Telling-off', 'noun'),
#  ('Again', 'adverb'),
#  ('Bottle', 'noun'),
#  ('Disharmony', 'noun'),
#  ('Hindsight', 'noun'),
#  ('Kilometre', 'noun'),
#  ('Packet', 'noun'),
#  ('Pallor', 'noun'),
#  ('En', 'noun'),
#  ('M.phil', 'noun'),
#  ('Inconsistent', 'adjective'),
#  ('Bob1', 'noun'),
#  ('Cheer', 'noun'),
#  ('Writ1', 'noun'),
#  ('Stabling', 'noun'),
#  ('Tepid', 'adjective'),
#  ('Calculator', 'noun'),
#  ('Expostulate', 'verb'),
#  ('Shanty1', 'noun'),
#  ('Plumber', 'noun'),
#  ('Knowingly', 'adverb'),
#  ('Gasholder', 'noun'),
#  ('Peruse', 'verb'),
#  ('Linear', 'adjective'),
#  ('Address', 'noun'),
#  ('Accede', 'verb'),
#  ('Cross-legged', 'adjective'),
#  ('Elixir', 'noun'),
#  ('Crossbow', 'noun'),
#  ('Swig', 'noun'),
#  ('Devils-on-horseback', 'noun'),
#  ('Spool', 'noun'),
#  ('Pr', 'noun'),
#  ('Gnu', 'noun'),
#  ('West-south-west', 'noun'),
#  ('Tuscan', 'noun'),
#  ('Weighting', 'noun'),
#  ('Skilful', 'adjective'),
#  ('Nobleman', 'noun'),
#  ('Scoria', 'noun'),
#  ('Tonsillitis', 'noun'),
#  ('Swizzle-stick', 'noun'),
#  ('Intuition', 'noun'),
#  ('Batsman', 'noun'),
#  ('Award', 'noun'),
#  ('Tout', 'noun'),
#  ('Snowmobile', 'noun'),
#  ('Scouse', 'noun'),
#  ('Tympanum', 'noun'),
#  ('Jogtrot', 'noun'),
#  ('Amputate', 'verb'),
#  ('Tope', 'verb'),
#  ('Sealant', 'noun'),
#  ('Close', 'noun'),
#  ('Yeti', 'noun'),
#  ('Well-groomed', 'adjective'),
#  ('Feast', 'noun'),
#  ('Oracle', 'noun'),
#  ('Folklore', 'noun'),
#  ('Absent', 'noun'),
#  ('Tera-', 'noun'),
#  ('Helio-', 'noun'),
#  ('Tulip', 'noun'),
#  ('Shock', 'noun'),
#  ('Input', 'noun'),
#  ('Swagger', 'noun'),
#  ('Recusant', 'noun'),
#  ('Toad-in-the-hole', 'noun'),
#  ('Public', 'noun'),
#  ('Funerary', 'adjective'),
#  ('Spellbind', 'verb'),
#  ('Powder-room', 'noun'),
#  ('Bias', 'noun'),
#  ('On-street', 'adjective'),
#  ('Furious', 'adjective'),
#  ('Half-term', 'noun'),
#  ('Shetland', 'noun'),
#  ('Emetic', 'noun'),
#  ('Toddy', 'noun'),
#  ('Deception', 'noun'),
#  ('Trade', 'noun'),
#  ('Condenser', 'noun'),
#  ('Hob', 'noun'),
#  ('Habitué', 'noun'),
#  ('Fab', 'adjective'),
#  ('Joke', 'noun'),
#  ('Hefty', 'adjective'),
#  ('Carbine', 'noun'),
#  ('Lj', 'noun'),
#  ('Encephalitis', 'noun'),
#  ('Gall1', 'noun'),
#  ('Hard', 'noun'),
#  ('Élan', 'noun'),
#  ('Defalcation', 'noun'),
#  ('Machine', 'noun'),
#  ('Underarm', 'noun'),
#  ('Endmost', 'adjective'),
#  ('Ll', 'noun'),
#  ('Black', 'noun'),
#  ('Synchronous', 'adjective'),
#  ('Granny', 'noun'),
#  ('Overview', 'noun'),
#  ('Complementary', 'noun'),
#  ('Sander', 'noun'),
#  ('Hepta-', 'noun'),
#  ('Croissant', 'noun'),
#  ('Fern', 'noun'),
#  ('Hydrofoil', 'noun'),
#  ('Townsfolk', 'noun'),
#  ('Bow-tie', 'noun'),
#  ('Unnerve', 'verb'),
#  ('Voracious', 'adjective'),
#  ('Overlie', 'verb'),
#  ('Midsummer', 'noun'),
#  ('Melon', 'noun'),
#  ('Face', 'adverb'),
#  ('Cater', 'verb'),
#  ('Higher', 'noun'),
#  ('Robust', 'adjective'),
#  ('Unprecedented', 'adjective'),
#  ('Uptight', 'adjective'),
#  ('Hand-over', 'noun'),
#  ('Compact1', 'noun'),
#  ('Unreflecting', 'adjective'),
#  ('Birthstone', 'noun'),
#  ('Spandrel', 'noun'),
#  ('Usage', 'adjective'),
#  ('Internal', 'adjective'),
#  ('Bone', 'noun'),
#  ('Tropical', 'adjective'),
#  ('Breathe', 'verb'),
#  ('Languish', 'verb'),
#  ('Damsel', 'noun'),
#  ('Metacarpus', 'noun'),
#  ('Haggis', 'noun'),
#  ('Headwaters', 'noun'),
#  ('Flightless', 'adjective'),
#  ('Hermitage', 'noun'),
#  ('Cinnamon', 'noun'),
#  ('Glut', 'noun'),
#  ('Matter', 'noun'),
#  ('Antenna', 'noun'),
#  ('Mock-up', 'noun'),
#  ('Treat', 'noun'),
#  ('Fantasia', 'noun'),
#  ('Bouncer', 'noun'),
#  ('Barque', 'noun'),
#  ('Lactic', 'adjective'),
#  ('Uterus', 'noun'),
#  ('Crest', 'noun'),
#  ('Houseman', 'noun'),
#  ('Teletext', 'noun'),
#  ('Glutamate', 'noun'),
#  ('Masonic', 'adjective'),
#  ('Horse-brass', 'noun'),
#  ('Cashmere', 'noun'),
#  ('Mollusc', 'noun'),
#  ('Bijou', 'noun'),
#  ('Cf', 'noun'),
#  ('Evasive', 'adjective'),
#  ('Paraffin', 'noun'),
#  ('Like1', 'noun'),
#  ('Insignificant', 'adjective'),
#  ('Battering-ram', 'noun'),
#  ('Newscast', 'noun'),
#  ('Vet1', 'noun'),
#  ('Kiss', 'noun'),
#  ('Centrist', 'noun'),
#  ('Genie', 'noun'),
#  ('Reverential', 'noun'),
#  ('Instigate', 'verb'),
#  ('Venturesome', 'adjective'),
#  ('Sherd', 'noun'),
#  ('Endeavour', 'noun'),
#  ('Sixpenny', 'adjective'),
#  ('Unthinking', 'adjective'),
#  ('Process1', 'noun'),
#  ('Kwh', 'noun'),
#  ('Bonk', 'noun'),
#  ('Stiletto', 'noun'),
#  ('Gold-field', 'noun'),
#  ('Q2', 'noun'),
#  ('Gallon', 'noun'),
#  ('Sitka', 'noun'),
#  ('Mainsail', 'noun'),
#  ('Mandrel', 'noun'),
#  ('Secretary-general', 'noun'),
#  ('Polyp', 'noun'),
#  ('Corsage', 'noun'),
#  ('Unemployed', 'adjective'),
#  ('Gag', 'noun'),
#  ('End', 'noun'),
#  ('Briton', 'noun'),
#  ('Ring', 'noun'),
#  ('Upshot', 'noun'),
#  ('Ballot', 'noun'),
#  ('Horn', 'noun'),
#  ('Pedophile', 'noun'),
#  ('Leisure', 'noun'),
#  ('Retroactive', 'adjective'),
#  ('Surmise', 'noun'),
#  ('Inspire', 'verb'),
#  ('Seating', 'noun'),
#  ('Despondent', 'adjective'),
#  ('Vertex', 'noun'),
#  ('Usage', 'verb'),
#  ('Gb', 'noun'),
#  ('Armhole', 'noun'),
#  ('Handrail', 'noun'),
#  ('Hagridden', 'adjective'),
#  ('Unlock', 'verb'),
#  ('Working', 'noun'),
#  ('Soft', 'noun'),
#  ('Ripen', 'verb'),
#  ('Ep', 'noun'),
#  ('Vv', 'noun'),
#  ('Wild', 'noun'),
#  ('Escapade', 'noun'),
#  ('Cyclic', 'adjective'),
#  ('Articled', 'noun'),
#  ('Tum', 'noun'),
#  ('Cosec', 'noun'),
#  ('Pontoon1', 'noun'),
#  ('Ashcan', 'noun'),
#  ('Expletive', 'noun'),
#  ('Mannish', 'adjective'),
#  ('Stair', 'noun'),
#  ('Housebreaking', 'noun'),
#  ('Volte-face', 'noun'),
#  ('Heap', 'noun'),
#  ('Southern', 'adjective'),
#  ('Goodbye', 'noun'),
#  ('Quadrate', 'noun'),
#  ('Pipeclay', 'noun'),
#  ('Serps', 'noun'),
#  ('Won', 'noun'),
#  ('Historicism', 'noun'),
#  ('Allusion', 'noun'),
#  ('Caa', 'noun'),
#  ('Dumb-bell', 'noun'),
#  ('Hooked', 'adjective'),
#  ('Glasnost', 'noun'),
#  ('Montage', 'noun'),
#  ('Millwright', 'noun'),
#  ('Ms', 'noun'),
#  ('Fatherly', 'adjective'),
#  ('Hydrogen', 'noun'),
#  ('Tithe', 'noun'),
#  ('Wheel-spin', 'noun'),
#  ('Re-engage', 'verb'),
#  ('Manifesto', 'noun'),
#  ('Col.', 'noun'),
#  ('Tench', 'noun'),
#  ('Indecorous', 'adjective'),
#  ('Whiten', 'verb'),
#  ('Armorial', 'adjective'),
#  ('Heck', 'noun'),
#  ('Fat', 'noun'),
#  ('Lib', 'noun'),
#  ('Fluoride', 'noun'),
#  ('Titian', 'adjective'),
#  ('Georgian2', 'noun'),
#  ('Acme', 'noun'),
#  ('Dog', 'noun'),
#  ('Countryside', 'noun'),
#  ('Proscenium', 'noun'),
#  ('Unexposed', 'adjective'),
#  ('Sterile', 'adjective'),
#  ('Minestrone', 'noun'),
#  ('Cake', 'noun'),
#  ('Coronary', 'noun'),
#  ('Pulmonary', 'adjective'),
#  ('Imprecation', 'noun'),
#  ('Snowcap', 'noun'),
#  ('Prim', 'adjective'),
#  ('Canonist', 'noun'),
#  ('Fall', 'noun'),
#  ('Lordly', 'adjective'),
#  ('Deceive', 'verb'),
#  ('Proponent', 'noun'),
#  ('Twilit', 'adjective'),
#  ('Vivisect', 'verb'),
#  ('Weeds', 'noun'),
#  ('Yellow-belly', 'noun'),
#  ('Reissue', 'noun'),
#  ('Diplomatic', 'noun'),
#  ('Seed-pearl', 'noun'),
#  ('Jinx', 'noun'),
#  ('Other', 'noun'),
#  ('Handmaid', 'noun'),
#  ('Crème', 'noun'),
#  ('Antinovel', 'noun'),
#  ('Serried', 'adjective'),
#  ('Twelfth', 'noun'),
#  ('Cockroach', 'noun'),
#  ('Outset', 'noun'),
#  ('Staging', 'noun'),
#  ('Anticlerical', 'adjective'),
#  ('Dispensary', 'noun'),
#  ('Peruke', 'noun'),
#  ('Alfresco', 'adverb'),
#  ('Callous', 'adjective'),
#  ('Chaff', 'noun'),
#  ('Usage', 'verb'),
#  ('Hornet', 'noun'),
#  ('Misbehave', 'verb'),
#  ('Thicken', 'verb'),
#  ('Property', 'noun'),
#  ('Greenwich', 'noun'),
#  ('Mostly', 'adverb'),
#  ('P3', 'noun'),
#  ('Pain', 'noun'),
#  ('Leuco-', 'noun'),
#  ('Pre-raphaelite', 'noun'),
#  ('Wodge', 'noun'),
#  ('Head', 'noun'),
#  ('Rusticate', 'verb'),
#  ('Nowt', 'noun'),
#  ('Fire-watcher', 'noun'),
#  ('Cable', 'noun'),
#  ('Protuberant', 'adjective'),
#  ('Fosse', 'noun'),
#  ('Heteromorphic', 'adjective'),
#  ('Riviera', 'noun'),
#  ('Rateable', 'noun'),
#  ('Amalgam', 'noun'),
#  ('Tile', 'noun'),
#  ('Oversleep', 'verb'),
#  ('Peregrine', 'noun'),
#  ('Namely', 'adverb'),
#  ('Unfit', 'adjective'),
#  ('Ferocious', 'adjective'),
#  ('Uncooked', 'adjective'),
#  ('Greeny', 'adjective'),
#  ('Loam', 'noun'),
#  ('Franc', 'noun'),
#  ('Scalp', 'noun'),
#  ('White', 'noun'),
#  ('Escalate', 'verb'),
#  ('Niacin', 'noun'),
#  ('Emery-board', 'noun'),
#  ('Sodium', 'noun'),
#  ('Overweight', 'noun'),
#  ('Inmate', 'noun'),
#  ('Nazi', 'noun'),
#  ('Die-casting', 'noun'),
#  ('Telemessage', 'noun'),
#  ('Great', 'noun'),
#  ('Hook', 'noun'),
#  ('Bladder', 'noun'),
#  ('Goner', 'noun'),
#  ('Firefly', 'noun'),
#  ('Robbery', 'noun'),
#  ('Indirect', 'noun'),
#  ('Irregular', 'noun'),
#  ('Eocene', 'noun'),
#  ('Acellular', 'adjective'),
#  ('Take-away', 'noun'),
#  ('Derring-do', 'noun'),
#  ('Pin-up', 'noun'),
#  ('Equilibrium', 'noun'),
#  ('Quondam', 'noun'),
#  ('Cenobite', 'noun'),
#  ('Ill-natured', 'adjective'),
#  ('Plaudit', 'noun'),
#  ('Subfusc', 'noun'),
#  ('Gd', 'noun'),
#  ('Has', 'noun'),
#  ('Grindstone', 'noun'),
#  ('Paddle1', 'noun'),
#  ('Gleeful', 'adjective'),
#  ('Ruminate', 'verb'),
#  ('Catalyze', 'verb'),
#  ('Self-service', 'noun'),
#  ('Flock-paper', 'noun'),
#  ('Ko', 'noun'),
#  ('Summer-house', 'noun'),
#  ('Edible', 'adjective'),
#  ('West-north-west', 'noun'),
#  ('Cremate', 'verb'),
#  ('Fluid', 'noun'),
#  ('Hg', 'noun'),
#  ('High', 'noun'),
#  ('Transform', 'verb'),
#  ('Gap', 'noun'),
#  ('Progressive', 'noun'),
#  ('Scalene', 'adjective'),
#  ('Facts', 'noun'),
#  ('Orange', 'noun'),
#  ('Copartner', 'noun'),
#  ('Usage', 'noun'),
#  ('Revalue', 'verb'),
#  ('Geisha', 'noun'),
#  ('Spidery', 'adjective'),
#  ('Severe', 'adjective'),
#  ('Iq', 'noun'),
#  ('Chinese', 'noun'),
#  ('Leaden', 'adjective'),
#  ('Parabola', 'noun'),
#  ('Incubation', 'noun'),
#  ('Lacquer', 'noun'),
#  ('Telegraphic', 'adjective'),
#  ('Chimera', 'noun'),
#  ('Carbohydrate', 'noun'),
#  ('Dace', 'noun'),
#  ('Previous', 'noun'),
#  ('Dinner', 'noun'),
#  ('Plain', 'noun'),
#  ('Preventive', 'noun'),
#  ('Topsail', 'noun'),
#  ('Food', 'noun'),
#  ('Villa', 'noun'),
#  ('Scrump', 'verb'),
#  ('Unlicensed', 'adjective'),
#  ('Anarchism', 'noun'),
#  ('Yiddish', 'noun'),
#  ('Correspondence', 'noun'),
#  ('Modem', 'noun'),
#  ('Pianoforte', 'noun'),
#  ('Bust-up', 'noun'),
#  ('Dissent', 'noun'),
#  ('Lodestar', 'noun'),
#  ('Codfish', 'noun'),
#  ('Messrs', 'noun'),
#  ('Diamond', 'noun'),
#  ('Jackass', 'noun'),
#  ('Garner', 'noun'),
#  ('Brain', 'noun'),
#  ('Herbaceous', 'adjective'),
#  ('Terms', 'noun'),
#  ('Consumerism', 'noun'),
#  ('Prophetic', 'adjective'),
#  ('Bin-liner', 'noun'),
#  ('Linage', 'noun'),
#  ('Wagoner', 'noun'),
#  ('Rich', 'adjective'),
#  ('Lw', 'noun'),
#  ('Money', 'noun'),
#  ('Wonderland', 'noun'),
#  ('Cub', 'noun'),
#  ('Delirious', 'adjective'),
#  ('Cardboard', 'noun'),
#  ('Clutter', 'noun'),
#  ('Lichen', 'noun'),
#  ('Yummy', 'adjective'),
#  ('Lighter-than-air', 'noun'),
#  ('Sigh', 'noun'),
#  ('Microbe', 'noun'),
#  ('Folkweave', 'noun'),
#  ('Ridiculous', 'adjective'),
#  ('Burette', 'noun'),
#  ('Nightjar', 'noun'),
#  ('Not', 'adverb'),
#  ('Strife', 'noun'),
#  ('Birch', 'noun'),
#  ('Viscera', 'noun'),
#  ('Dramatize', 'verb'),
#  ('Ormolu', 'noun'),
#  ('Scarify2', 'verb'),
#  ('Tenpin', 'noun'),
#  ('Levant', 'noun'),
#  ('Henge', 'noun'),
#  ('Excreta', 'noun'),
#  ('Crew', 'noun'),
#  ('Daff', 'noun'),
#  ('Sequel', 'noun'),
#  ('Private', 'noun'),
#  ('Blazer', 'noun'),
#  ('Flipper', 'noun'),
#  ('Stockjobber', 'noun'),
#  ('Lumber', 'noun'),
#  ('Slime', 'noun'),
#  ('Usage', 'noun'),
#  ('Misjudge', 'verb'),
#  ('Queen', 'noun'),
#  ('Renounce', 'verb'),
#  ('O3', 'noun'),
#  ('Dissonant', 'adjective'),
#  ('Policeman', 'noun'),
#  ('Cut-price', 'adjective'),
#  ('Plate-rack', 'noun'),
#  ('Scary', 'adjective'),
#  ('Headlight', 'noun'),
#  ('Parapsychology', 'noun'),
#  ('Primula', 'noun'),
#  ('Marsh', 'noun'),
#  ('Apostolic', 'noun'),
#  ('Seasoning', 'noun'),
#  ('Customary', 'adjective'),
#  ('Rodomontade', 'noun'),
#  ('Electronics', 'noun'),
#  ('Corolla', 'noun'),
#  ('Corn', 'noun'),
#  ('Pollack', 'noun'),
#  ('Trinity', 'noun'),
#  ('Individually', 'adverb'),
#  ('Traipse', 'noun'),
#  ('Extended', 'noun'),
#  ('Less', 'noun'),
#  ('Mystery', 'noun'),
#  ('Derby', 'noun'),
#  ('Diopter', 'noun'),
#  ('S2', 'noun'),
#  ('Unobserved', 'adjective'),
#  ('Flounce1', 'noun'),
#  ('Buffer', 'noun'),
#  ('Northeaster', 'noun'),
#  ('Sporran', 'noun'),
#  ('Lump', 'noun'),
#  ('Scrape', 'noun'),
#  ('Test-tube', 'noun'),
#  ('Self-confident', 'adjective'),
#  ('Feu', 'noun'),
#  ('Wartime', 'noun'),
#  ('Swamp', 'noun'),
#  ('Sylph', 'noun'),
#  ('Homicide', 'noun'),
#  ('Doner', 'noun'),
#  ('Umbrage', 'noun'),
#  ('Kindly1', 'adverb'),
#  ('Synthesizer', 'noun'),
#  ('Herpes', 'noun'),
#  ('Proximo', 'adjective'),
#  ('Starling', 'noun'),
#  ('Tumble-drier', 'noun'),
#  ('Brushwork', 'noun'),
#  ('Exclude', 'verb'),
#  ('Jekyll', 'noun'),
#  ('Misanthrope', 'noun'),
#  ('Machinery', 'noun'),
#  ('Waged', 'adjective'),
#  ('Ingenuous', 'adjective'),
#  ('Stunning', 'adjective'),
#  ('Valium', 'noun'),
#  ('Choler', 'noun'),
#  ('Biotin', 'noun'),
#  ('Teeny-bopper', 'noun'),
#  ('Upswing', 'noun'),
#  ('Efficacious', 'adjective'),
#  ('Townspeople', 'noun'),
#  ('Consumption', 'noun'),
#  ('Uncombed', 'adjective'),
#  ('Florin', 'noun'),
#  ('Robe', 'noun'),
#  ('Bailey', 'noun'),
#  ('Twice', 'adverb'),
#  ('Psalmist', 'noun'),
#  ('Largo', 'noun'),
#  ('Remark', 'noun'),
#  ('Unparalleled', 'adjective'),
#  ('Coconut', 'noun'),
#  ('Mastoid', 'noun'),
#  ('Dampen', 'verb'),
#  ('Hmg', 'noun'),
#  ('Dust', 'noun'),
#  ('Acropolis', 'noun'),
#  ('Country', 'noun'),
#  ('Drop', 'noun'),
#  ('Figure-skating', 'noun'),
#  ('Patch', 'noun'),
#  ('Convent', 'noun'),
#  ('Tsunami', 'noun'),
#  ('Prosperous', 'adjective'),
#  ('Embarrass', 'verb'),
#  ('Podgy', 'adjective'),
#  ('Genuflect', 'verb'),
#  ('Table', 'noun'),
#  ('Puss', 'noun'),
#  ('Red-handed', 'adverb'),
#  ('Abduct', 'verb'),
#  ('Wholemeal', 'noun'),
#  ('Statistic', 'noun'),
#  ('Overheat', 'verb'),
#  ('Irrepressible', 'adjective'),
#  ('Politician', 'noun'),
#  ('Fatstock', 'noun'),
#  ('Electrolyze', 'verb'),
#  ('From', 'noun'),
#  ('Guelder', 'noun'),
#  ('Unwitting', 'adjective'),
#  ('Underskirt', 'noun'),
#  ('Apache', 'noun'),
#  ('Racketeer', 'noun'),
#  ('Shake', 'noun'),
#  ('V.g.c', 'noun'),
#  ('Lounge', 'noun'),
#  ('Croat', 'adjective'),
#  ('Octet', 'noun'),
#  ('Splendid', 'adjective'),
#  ('Zebu', 'noun'),
#  ('Showgirl', 'noun'),
#  ('Collective', 'noun'),
#  ('Mews', 'noun'),
#  ('Porthole', 'noun'),
#  ('Inter', 'verb'),
#  ('Dominican', 'noun'),
#  ('Blemish', 'noun'),
#  ('Chopsuey', 'noun'),
#  ('Repercussion', 'noun'),
#  ('Nay', 'noun'),
#  ('Pollard', 'noun'),
#  ('Kindred', 'noun'),
#  ('Restyle', 'verb'),
#  ('Restive', 'adjective'),
#  ('Defalcate', 'verb'),
#  ('Holler', 'verb'),
#  ('Jetty', 'noun'),
#  ('Atoll', 'noun'),
#  ('Resign', 'verb'),
#  ('Frustrate', 'verb'),
#  ('Ward', 'noun'),
#  ('Poteen', 'noun'),
#  ('Bandage', 'noun'),
#  ('Tod', 'noun'),
#  ('Vivacious', 'adjective'),
#  ('Adieu', 'noun'),
#  ('Lutetium', 'noun'),
#  ('Ref2', 'noun'),
#  ('Banderole', 'noun'),
#  ('Terse', 'adjective'),
#  ('Abide', 'verb'),
#  ('Date1', 'noun'),
#  ('Epidemic', 'noun'),
#  ('Autumn', 'noun'),
#  ('Chartered', 'noun'),
#  ('Whack', 'noun'),
#  ('Leveller', 'noun'),
#  ('Upswept', 'adjective'),
#  ('Ink', 'noun'),
#  ('Undesirable', 'noun'),
#  ('Austerity', 'noun'),
#  ('Seat-belt', 'noun'),
#  ('Sexy', 'adjective'),
#  ('Knapsack', 'noun'),
#  ('Flibbertigibbet', 'noun'),
#  ('Maelstrom', 'noun'),
#  ('Iron', 'noun'),
#  ('Self-deprecation', 'noun'),
#  ('Cloy', 'verb'),
#  ('Kisser', 'noun'),
#  ('Wave', 'noun'),
#  ('Order', 'noun'),
#  ('Masturbate', 'verb'),
#  ('Signpost', 'noun'),
#  ('Racetrack', 'noun'),
#  ('Necropolis', 'noun'),
#  ('Blusher', 'noun'),
#  ('Gloaming', 'noun'),
#  ('Eschew', 'verb'),
#  ('Covey', 'noun'),
#  ('Tab1', 'noun'),
#  ('Lead1', 'noun'),
#  ('Guarantee', 'noun'),
#  ('Guise', 'noun'),
#  ('Dammit', 'noun'),
#  ('Plentiful', 'adjective'),
#  ('A/c', 'noun'),
#  ('Clement', 'adjective'),
#  ('Mis-2', 'noun'),
#  ('Illustration', 'noun'),
#  ('Uninterrupted', 'adjective'),
#  ('Heatwave', 'noun'),
#  ('Patrol', 'noun'),
#  ('Goatee', 'noun'),
#  ('Groupie', 'noun'),
#  ('Privy', 'noun'),
#  ('Remote', 'noun'),
#  ('Jersey', 'noun'),
#  ('Full-blown', 'adjective'),
#  ('Cry-baby', 'noun'),
#  ('Grandma', 'noun'),
#  ('Bathhouse', 'noun'),
#  ('Flung', 'verb'),
#  ('Decarbonize', 'verb'),
#  ('Hind1', 'adjective'),
#  ('Stellar', 'adjective'),
#  ('Hence', 'adverb'),
#  ('Six-shooter', 'noun'),
#  ('Canaille', 'noun'),
#  ('Respect', 'noun'),
#  ('Junk2', 'noun'),
#  ('Parkinson', 'noun'),
#  ('Ichneumon', 'noun'),
#  ('Dm', 'noun'),
#  ('Par', 'adverb'),
#  ('Freshman', 'noun'),
#  ('Shuffle', 'noun'),
#  ('Unperson', 'noun'),
#  ('Huguenot', 'noun'),
#  ('Superintend', 'verb'),
#  ('Usage', 'noun'),
#  ('Unfilled', 'adjective'),
#  ('Scope', 'noun'),
#  ('Blueprint', 'noun'),
#  ('Lb', 'noun'),
#  ('Hittite', 'noun'),
#  ('Ensign', 'noun'),
#  ('Heave', 'noun'),
#  ('Spore', 'noun'),
#  ('Backyard', 'noun'),
#  ('Self-defeating', 'adjective'),
#  ('Isolationism', 'noun'),
#  ('Conchology', 'noun'),
#  ('Terrier', 'noun'),
#  ('Customer', 'noun'),
#  ('Reveille', 'noun'),
#  ('Refectory', 'noun'),
#  ('Breeding', 'noun'),
#  ('Willy', 'noun'),
#  ('Speechless', 'adjective'),
#  ('Groundless', 'adjective'),
#  ('Football', 'noun'),
#  ('Sex', 'noun'),
#  ('Residence', 'noun'),
#  ('Empyrean', 'noun'),
#  ('Metallic', 'adjective'),
#  ('Haka', 'noun'),
#  ('Truck1', 'noun'),
#  ('Unspecified', 'adjective'),
#  ('Oakum', 'noun'),
#  ('Haw1', 'noun'),
#  ('Mod', 'noun'),
#  ('Relegate', 'verb'),
#  ('Digital', 'noun'),
#  ('Moist', 'adjective'),
#  ('Identical', 'adjective'),
#  ('Acceptance', 'noun'),
#  ('Reunify', 'verb'),
#  ('Leukaemia', 'noun'),
#  ('Millepede', 'noun'),
#  ('Shock2', 'noun'),
#  ('Shelve', 'verb'),
#  ('Hf', 'noun'),
#  ('Joint', 'noun'),
#  ('Hols', 'noun'),
#  ('Hugely', 'adverb'),
#  ('Encyclopedic', 'adjective'),
#  ('Us', 'noun'),
#  ('Mange-tout', 'noun'),
#  ('Prescriptive', 'adjective'),
#  ('Ensilage', 'noun'),
#  ('Pas', 'noun'),
#  ('Trying', 'adjective'),
#  ('Preconceive', 'verb'),
#  ('Henry', 'noun'),
#  ('Edgeways', 'adverb'),
#  ('Pandemonium', 'noun'),
#  ('Appliance', 'noun'),
#  ('Hydrology', 'noun'),
#  ('Highland', 'noun'),
#  ('Home-coming', 'noun'),
#  ('Proton', 'noun'),
#  ('Streak', 'noun'),
#  ('Mitigate', 'verb'),
#  ('Abhorrence', 'noun'),
#  ('Burn-out', 'noun'),
#  ('Diwali', 'noun'),
#  ('Yeoman', 'noun'),
#  ('Seal1', 'noun'),
#  ('Stint', 'noun'),
#  ('Mound', 'noun'),
#  ('Abundance', 'noun'),
#  ('Diaper', 'noun'),
#  ('Second', 'noun'),
#  ('Mastoid', 'noun'),
#  ('Hg', 'noun'),
#  ('Tuning-fork', 'noun'),
#  ('Crockery', 'noun'),
#  ('Open-handed', 'adjective'),
#  ('Corned', 'adjective'),
#  ('Sids', 'noun'),
#  ('Etiquette', 'noun'),
#  ('Reagent', 'noun'),
#  ('Jezebel', 'noun'),
#  ('Wright', 'noun'),
#  ('Wrong', 'noun'),
#  ('Cres', 'noun'),
#  ('Gilt1', 'noun'),
#  ('Usage', 'noun'),
#  ('Safety-belt', 'noun'),
#  ('Flip-flop', 'noun'),
#  ('Witches', 'noun'),
#  ('Yorkist', 'noun'),
#  ('Imperturbable', 'adjective'),
#  ('Scissors', 'noun'),
#  ('Devolution', 'noun'),
#  ('Ordinand', 'noun'),
#  ('Adrift', 'adverb'),
#  ('Tableau', 'noun'),
#  ('Helping', 'noun'),
#  ('Monkey', 'noun'),
#  ('Olive', 'noun'),
#  ('Flier', 'noun'),
#  ('Spiraea', 'noun'),
#  ('Regatta', 'noun'),
#  ('Californium', 'noun'),
#  ('Glaze', 'noun'),
#  ('Chipboard', 'noun'),
#  ('Clinical', 'adjective'),
#  ('Piccolo', 'noun'),
#  ('Soapy', 'adjective'),
#  ('Raison', 'noun'),
#  ('Renumber', 'verb'),
#  ('Dogfight', 'noun'),
#  ('Crossbones', 'noun'),
#  ('Passion-play', 'noun'),
#  ('House-agent', 'noun'),
#  ('Tanh', 'noun'),
#  ('Resentment', 'noun'),
#  ('Livable', 'noun'),
#  ('Mormon', 'noun'),
#  ('Flight', 'noun'),
#  ('Scrub1', 'noun'),
#  ('Allen', 'noun'),
#  ('Helot', 'noun'),
#  ('Labour-saving', 'adjective'),
#  ('Hack1', 'noun'),
#  ('Treasury', 'noun'),
#  ('Turkish', 'noun'),
#  ('Epicenter', 'noun'),
#  ('Dyspepsia', 'noun'),
#  ('Calcine', 'verb'),
#  ('Smooth-tongued', 'adjective'),
#  ('Anemometer', 'noun'),
#  ('Gran', 'noun'),
#  ('Drawl', 'noun'),
#  ('Robotics', 'noun'),
#  ('Encourage', 'verb'),
#  ('Sinew', 'noun'),
#  ('Wannabe', 'noun'),
#  ('Wren', 'noun'),
#  ('Builder', 'noun'),
#  ('Fire-screen', 'noun'),
#  ('Stampede', 'noun'),
#  ('Typhus', 'noun'),
#  ('Self-governing', 'adjective'),
#  ('Cervical', 'adjective'),
#  ('Pillage', 'noun'),
#  ('Starveling', 'noun'),
#  ('Brace', 'noun'),
#  ('Tilth', 'noun'),
#  ('Hydro', 'noun'),
#  ('Resonant', 'adjective'),
#  ('Hypertext', 'noun'),
#  ('Plump2', 'noun'),
#  ('Lend', 'verb'),
#  ('Tacky2', 'adjective'),
#  ('Urgent', 'adjective'),
#  ('Timorous', 'adjective'),
#  ('Calorific', 'adjective'),
#  ('Hamitic', 'noun'),
#  ('Teak', 'noun'),
#  ('Puff', 'noun'),
#  ('Pauper', 'noun'),
#  ('Underlying', 'noun'),
#  ('Hegira', 'noun'),
#  ('Discontent', 'noun'),
#  ('Abyss', 'noun'),
#  ('Hidden', 'noun'),
#  ('Cassava', 'noun'),
#  ('Scrip', 'noun'),
#  ('Hotfoot', 'noun'),
#  ('Indecent', 'noun'),
#  ('Griffon', 'noun'),
#  ('Tea', 'noun'),
#  ('Directly', 'noun'),
#  ('Water-meadow', 'noun'),
#  ('Undermanned', 'adjective'),
#  ('Jiggery-pokery', 'noun'),
#  ('Hydro-', 'noun'),
#  ('Access', 'noun'),
#  ('Perjure', 'noun'),
#  ('Hammer-toe', 'noun'),
#  ('Per-', 'noun'),
#  ('Afternoon', 'noun'),
#  ('Brasserie', 'noun'),
#  ('Opportune', 'adjective'),
#  ('Last', 'noun'),
#  ('Cheese', 'noun'),
#  ('Dithyramb', 'noun'),
#  ('Per', 'verb'),
#  ('Fuse1', 'noun'),
#  ('Heather', 'noun'),
#  ('Power-sharing', 'noun'),
#  ('Let1', 'noun'),
#  ('Miracle', 'noun'),
#  ('Ai', 'noun'),
#  ('Logbook', 'noun'),
#  ('Submersible', 'noun'),
#  ('Hamper2', 'verb'),
#  ('Present2', 'verb'),
#  ('Ask', 'verb'),
#  ('Identification', 'noun'),
#  ('African', 'noun'),
#  ('Seaside', 'noun'),
#  ('Offhand', 'noun'),
#  ('Cultured', 'noun'),
#  ('Touching', 'noun'),
#  ('Dismal', 'adjective'),
#  ('Fetching', 'adjective'),
#  ('Orthography', 'noun'),
#  ('High', 'noun'),
#  ('Unpunished', 'adjective'),
#  ('Unfulfilled', 'adjective'),
#  ('Olfactory', 'adjective'),
#  ('Heyday', 'noun'),
#  ('Modus', 'noun'),
#  ('Weaponry', 'noun'),
#  ('Trance', 'noun'),
#  ('Homophone', 'noun'),
#  ('Crudités', 'noun'),
#  ('Meat', 'noun'),
#  ('Litt.d', 'noun'),
#  ('Heath', 'adjective'),
#  ('Degeneration', 'noun'),
#  ('Hearten', 'verb'),
#  ('Wale', 'noun'),
#  ('Atavism', 'noun'),
#  ('Water-pistol', 'noun'),
#  ('Fulminant', 'adjective'),
#  ('Necessitous', 'adjective'),
#  ('Bob3', 'noun'),
#  ('Far', 'adverb'),
#  ('Hoary', 'adjective'),
#  ('Gull2', 'verb'),
#  ('Paginate', 'verb'),
#  ('Contrary', 'noun'),
#  ('Sj', 'noun'),
#  ('Gob-stopper', 'noun'),
#  ('Confinement', 'noun'),
#  ('Cab', 'noun'),
#  ('Free', 'noun'),
#  ('Ritualism', 'noun'),
#  ('Gavel', 'noun'),
#  ('Ineducable', 'adjective'),
#  ('Presbyter', 'noun'),
#  ('Hair-raising', 'adjective'),
#  ('Barley', 'noun'),
#  ('Scurvy', 'noun'),
#  ('Warehouse', 'noun'),
#  ('Drink', 'noun'),
#  ('Unforgiving', 'adjective'),
#  ('Accomplishment', 'noun'),
#  ('Hike', 'noun'),
#  ('Hand', 'noun'),
#  ('Perpetuate', 'verb'),
#  ('Peevish', 'adjective'),
#  ...]

# %%
featuresets = [(word_features(n), word) for (n, word) in labeled_words]

# %%
featuresets
# Out:
# [({'starting_letter': 'T',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 's',
#    'last2_letters': 'ps',
#    'last3_letters': 'Pps'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'ken'},
#   'verb'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'tte'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'dle'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'ue',
#    'last3_letters': 'lue'},
#   'noun'),
#  ({'starting_letter': 'V',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'ium'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'd',
#    'last2_letters': 'id',
#    'last3_letters': 'aid'},
#   'adjective'),
#  ({'starting_letter': 'A',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ost'},
#   'adverb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'ny',
#    'last3_letters': 'nny'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'y',
#    'last2_letters': 'py',
#    'last3_letters': 'ppy'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'k',
#    'last2_letters': 'nk',
#    'last3_letters': 'unk'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ole'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'n',
#    'last2_letters': 'En',
#    'last3_letters': 'En'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'cot'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'gal'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'rd',
#    'last3_letters': 'ord'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'tel'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'y',
#    'last2_letters': 'ty',
#    'last3_letters': 'ity'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ure'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'e',
#    'last2_letters': 'me',
#    'last3_letters': 'ome'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ler'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'gy',
#    'last3_letters': 'ogy'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ke',
#    'last3_letters': 'ake'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ist'},
#   'verb'),
#  ({'starting_letter': 'L',
#    'last_letter': 'y',
#    'last2_letters': 'ty',
#    'last3_letters': 'ity'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': '1',
#    'last2_letters': 'r1',
#    'last3_letters': 'er1'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ule'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'gle'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'use'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ted'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'ty',
#    'last3_letters': 'ity'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'e',
#    'last2_letters': 'ze',
#    'last3_letters': 'ize'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'lic'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'k',
#    'last2_letters': 'nk',
#    'last3_letters': 'unk'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'm',
#    'last2_letters': 'am',
#    'last3_letters': 'ram'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'r',
#    'last2_letters': 'ar',
#    'last3_letters': 'ear'},
#   'verb'),
#  ({'starting_letter': 'R',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'y',
#    'last2_letters': 'fy',
#    'last3_letters': 'ify'},
#   'verb'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'bot'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'bus'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'fet'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'r',
#    'last2_letters': 'ir',
#    'last3_letters': 'air'},
#   'noun'),
#  ({'starting_letter': 'V',
#    'last_letter': 'r',
#    'last2_letters': 'ur',
#    'last3_letters': 'our'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'rt',
#    'last3_letters': 'ert'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'Set'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'f',
#    'last2_letters': 'ff',
#    'last3_letters': 'off'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'in',
#    'last3_letters': 'ain'},
#   'adverb'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'tle'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'y',
#    'last2_letters': 'ny',
#    'last3_letters': 'ony'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'noun'),
#  ({'starting_letter': 'K',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'tre'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'ket'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'or',
#    'last3_letters': 'lor'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'n',
#    'last2_letters': 'En',
#    'last3_letters': 'En'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'l',
#    'last2_letters': 'il',
#    'last3_letters': 'hil'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': '1',
#    'last2_letters': 'b1',
#    'last3_letters': 'ob1'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'eer'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': '1',
#    'last2_letters': 't1',
#    'last3_letters': 'it1'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'd',
#    'last2_letters': 'id',
#    'last3_letters': 'pid'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 'r',
#    'last2_letters': 'or',
#    'last3_letters': 'tor'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'S',
#    'last_letter': '1',
#    'last2_letters': 'y1',
#    'last3_letters': 'ty1'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ber'},
#   'noun'),
#  ({'starting_letter': 'K',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'gly'},
#   'adverb'),
#  ({'starting_letter': 'G',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'der'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'use'},
#   'verb'),
#  ({'starting_letter': 'L',
#    'last_letter': 'r',
#    'last2_letters': 'ar',
#    'last3_letters': 'ear'},
#   'adjective'),
#  ({'starting_letter': 'A',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'ess'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ede'},
#   'verb'),
#  ({'starting_letter': 'C',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ged'},
#   'adjective'),
#  ({'starting_letter': 'E',
#    'last_letter': 'r',
#    'last2_letters': 'ir',
#    'last3_letters': 'xir'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'w',
#    'last2_letters': 'ow',
#    'last3_letters': 'bow'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ig',
#    'last3_letters': 'wig'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'ack'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'l',
#    'last2_letters': 'ol',
#    'last3_letters': 'ool'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'Pr',
#    'last3_letters': 'Pr'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'u',
#    'last2_letters': 'nu',
#    'last3_letters': 'Gnu'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'est'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'can'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'l',
#    'last2_letters': 'ul',
#    'last3_letters': 'ful'},
#   'adjective'),
#  ({'starting_letter': 'N',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'man'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'a',
#    'last2_letters': 'ia',
#    'last3_letters': 'ria'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 's',
#    'last2_letters': 'is',
#    'last3_letters': 'tis'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'ick'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'man'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'd',
#    'last2_letters': 'rd',
#    'last3_letters': 'ard'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'ut',
#    'last3_letters': 'out'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ile'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'use'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'num'},
#   'noun'),
#  ({'starting_letter': 'J',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'rot'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'pe',
#    'last3_letters': 'ope'},
#   'verb'),
#  ({'starting_letter': 'S',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'ose'},
#   'noun'),
#  ({'starting_letter': 'Y',
#    'last_letter': 'i',
#    'last2_letters': 'ti',
#    'last3_letters': 'eti'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'med'},
#   'adjective'),
#  ({'starting_letter': 'F',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ast'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'cle'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ore'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': '-',
#    'last2_letters': 'a-',
#    'last3_letters': 'ra-'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': '-',
#    'last2_letters': 'o-',
#    'last3_letters': 'io-'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'p',
#    'last2_letters': 'ip',
#    'last3_letters': 'lip'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'ock'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'ut',
#    'last3_letters': 'put'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ger'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ole'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'lic'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'ind'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'm',
#    'last2_letters': 'om',
#    'last3_letters': 'oom'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 's',
#    'last2_letters': 'as',
#    'last3_letters': 'ias'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'eet'},
#   'adjective'),
#  ({'starting_letter': 'F',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'm',
#    'last2_letters': 'rm',
#    'last3_letters': 'erm'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'and'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'tic'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'y',
#    'last2_letters': 'dy',
#    'last3_letters': 'ddy'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ade'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ser'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'b',
#    'last2_letters': 'ob',
#    'last3_letters': 'Hob'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'é',
#    'last2_letters': 'ué',
#    'last3_letters': 'tué'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'b',
#    'last2_letters': 'ab',
#    'last3_letters': 'Fab'},
#   'adjective'),
#  ({'starting_letter': 'J',
#    'last_letter': 'e',
#    'last2_letters': 'ke',
#    'last3_letters': 'oke'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'y',
#    'last2_letters': 'ty',
#    'last3_letters': 'fty'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'ine'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'j',
#    'last2_letters': 'Lj',
#    'last3_letters': 'Lj'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 's',
#    'last2_letters': 'is',
#    'last3_letters': 'tis'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': '1',
#    'last2_letters': 'l1',
#    'last3_letters': 'll1'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'rd',
#    'last3_letters': 'ard'},
#   'noun'),
#  ({'starting_letter': 'É',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'lan'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'ine'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'm',
#    'last2_letters': 'rm',
#    'last3_letters': 'arm'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ost'},
#   'adjective'),
#  ({'starting_letter': 'L',
#    'last_letter': 'l',
#    'last2_letters': 'Ll',
#    'last3_letters': 'Ll'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'ack'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': 'y',
#    'last2_letters': 'ny',
#    'last3_letters': 'nny'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'w',
#    'last2_letters': 'ew',
#    'last3_letters': 'iew'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'der'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': '-',
#    'last2_letters': 'a-',
#    'last3_letters': 'ta-'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'n',
#    'last2_letters': 'rn',
#    'last3_letters': 'ern'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'l',
#    'last2_letters': 'il',
#    'last3_letters': 'oil'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'k',
#    'last2_letters': 'lk',
#    'last3_letters': 'olk'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ie',
#    'last3_letters': 'tie'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'rve'},
#   'verb'),
#  ({'starting_letter': 'V',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'O',
#    'last_letter': 'e',
#    'last2_letters': 'ie',
#    'last3_letters': 'lie'},
#   'verb'),
#  ({'starting_letter': 'M',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'mer'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'lon'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'e',
#    'last2_letters': 'ce',
#    'last3_letters': 'ace'},
#   'adverb'),
#  ({'starting_letter': 'C',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'verb'),
#  ({'starting_letter': 'H',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'her'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ust'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ted'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ver'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': '1',
#    'last2_letters': 't1',
#    'last3_letters': 'ct1'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'one'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'rel'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'adjective'),
#  ({'starting_letter': 'I',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'nal'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'one'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'cal'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'he',
#    'last3_letters': 'the'},
#   'verb'),
#  ({'starting_letter': 'L',
#    'last_letter': 'h',
#    'last2_letters': 'sh',
#    'last3_letters': 'ish'},
#   'verb'),
#  ({'starting_letter': 'D',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'sel'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'pus'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 's',
#    'last2_letters': 'is',
#    'last3_letters': 'gis'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 's',
#    'last2_letters': 'rs',
#    'last3_letters': 'ers'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'ess'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'mon'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 't',
#    'last2_letters': 'ut',
#    'last3_letters': 'lut'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'a',
#    'last2_letters': 'na',
#    'last3_letters': 'nna'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'p',
#    'last2_letters': 'up',
#    'last3_letters': '-up'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'at',
#    'last3_letters': 'eat'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'a',
#    'last2_letters': 'ia',
#    'last3_letters': 'sia'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'cer'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ue',
#    'last3_letters': 'que'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'tic'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'rus'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'est'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'man'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'xt',
#    'last3_letters': 'ext'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'nic'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'ass'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ere'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'c',
#    'last2_letters': 'sc',
#    'last3_letters': 'usc'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'u',
#    'last2_letters': 'ou',
#    'last3_letters': 'jou'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'f',
#    'last2_letters': 'Cf',
#    'last3_letters': 'Cf'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'ive'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'n',
#    'last2_letters': 'in',
#    'last3_letters': 'fin'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': '1',
#    'last2_letters': 'e1',
#    'last3_letters': 'ke1'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': 'm',
#    'last2_letters': 'am',
#    'last3_letters': 'ram'},
#   'noun'),
#  ({'starting_letter': 'N',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ast'},
#   'noun'),
#  ({'starting_letter': 'V',
#    'last_letter': '1',
#    'last2_letters': 't1',
#    'last3_letters': 'et1'},
#   'noun'),
#  ({'starting_letter': 'K',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'iss'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ist'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'e',
#    'last2_letters': 'ie',
#    'last3_letters': 'nie'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'ial'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'V',
#    'last_letter': 'e',
#    'last2_letters': 'me',
#    'last3_letters': 'ome'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'd',
#    'last2_letters': 'rd',
#    'last3_letters': 'erd'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'r',
#    'last2_letters': 'ur',
#    'last3_letters': 'our'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'y',
#    'last2_letters': 'ny',
#    'last3_letters': 'nny'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': '1',
#    'last2_letters': 's1',
#    'last3_letters': 'ss1'},
#   'noun'),
#  ({'starting_letter': 'K',
#    'last_letter': 'h',
#    'last2_letters': 'wh',
#    'last3_letters': 'Kwh'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'k',
#    'last2_letters': 'nk',
#    'last3_letters': 'onk'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'o',
#    'last2_letters': 'to',
#    'last3_letters': 'tto'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'd',
#    'last2_letters': 'ld',
#    'last3_letters': 'eld'},
#   'noun'),
#  ({'starting_letter': 'Q',
#    'last_letter': '2',
#    'last2_letters': 'Q2',
#    'last3_letters': 'Q2'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'lon'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'a',
#    'last2_letters': 'ka',
#    'last3_letters': 'tka'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'l',
#    'last2_letters': 'il',
#    'last3_letters': 'ail'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'rel'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'ral'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'p',
#    'last2_letters': 'yp',
#    'last3_letters': 'lyp'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'yed'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': 'g',
#    'last2_letters': 'ag',
#    'last3_letters': 'Gag'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'End'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ton'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'hot'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'lot'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'rn',
#    'last3_letters': 'orn'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ile'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ure'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'ive'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'ise'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ire'},
#   'verb'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'adjective'),
#  ({'starting_letter': 'V',
#    'last_letter': 'x',
#    'last2_letters': 'ex',
#    'last3_letters': 'tex'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'verb'),
#  ({'starting_letter': 'G',
#    'last_letter': 'b',
#    'last2_letters': 'Gb',
#    'last3_letters': 'Gb'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ole'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'l',
#    'last2_letters': 'il',
#    'last3_letters': 'ail'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'den'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'ock'},
#   'verb'),
#  ({'starting_letter': 'W',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 't',
#    'last2_letters': 'ft',
#    'last3_letters': 'oft'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'pen'},
#   'verb'),
#  ({'starting_letter': 'E',
#    'last_letter': 'p',
#    'last2_letters': 'Ep',
#    'last3_letters': 'Ep'},
#   'noun'),
#  ({'starting_letter': 'V',
#    'last_letter': 'v',
#    'last2_letters': 'Vv',
#    'last3_letters': 'Vv'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'd',
#    'last2_letters': 'ld',
#    'last3_letters': 'ild'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ade'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'lic'},
#   'adjective'),
#  ({'starting_letter': 'A',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'led'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'Tum'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'c',
#    'last2_letters': 'ec',
#    'last3_letters': 'sec'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': '1',
#    'last2_letters': 'n1',
#    'last3_letters': 'on1'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'can'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'ive'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'h',
#    'last2_letters': 'sh',
#    'last3_letters': 'ish'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'r',
#    'last2_letters': 'ir',
#    'last3_letters': 'air'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'V',
#    'last_letter': 'e',
#    'last2_letters': 'ce',
#    'last3_letters': 'ace'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'p',
#    'last2_letters': 'ap',
#    'last3_letters': 'eap'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'n',
#    'last2_letters': 'rn',
#    'last3_letters': 'ern'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': 'e',
#    'last2_letters': 'ye',
#    'last3_letters': 'bye'},
#   'noun'),
#  ({'starting_letter': 'Q',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'ay',
#    'last3_letters': 'lay'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 's',
#    'last2_letters': 'ps',
#    'last3_letters': 'rps'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'Won'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'm',
#    'last2_letters': 'sm',
#    'last3_letters': 'ism'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'a',
#    'last2_letters': 'aa',
#    'last3_letters': 'Caa'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'l',
#    'last2_letters': 'll',
#    'last3_letters': 'ell'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ked'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ost'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 's',
#    'last2_letters': 'Ms',
#    'last3_letters': 'Ms'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'rly'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'gen'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'he',
#    'last3_letters': 'the'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'n',
#    'last2_letters': 'in',
#    'last3_letters': 'pin'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'verb'),
#  ({'starting_letter': 'M',
#    'last_letter': 'o',
#    'last2_letters': 'to',
#    'last3_letters': 'sto'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': '.',
#    'last2_letters': 'l.',
#    'last3_letters': 'ol.'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'h',
#    'last2_letters': 'ch',
#    'last3_letters': 'nch'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'W',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'ten'},
#   'verb'),
#  ({'starting_letter': 'A',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'ial'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'k',
#    'last2_letters': 'ck',
#    'last3_letters': 'eck'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 't',
#    'last2_letters': 'at',
#    'last3_letters': 'Fat'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'b',
#    'last2_letters': 'ib',
#    'last3_letters': 'Lib'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ide'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'ian'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': '2',
#    'last2_letters': 'n2',
#    'last3_letters': 'an2'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'e',
#    'last2_letters': 'me',
#    'last3_letters': 'cme'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'g',
#    'last2_letters': 'og',
#    'last3_letters': 'Dog'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ide'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'ium'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'sed'},
#   'adjective'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ile'},
#   'adjective'),
#  ({'starting_letter': 'M',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'one'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'ke',
#    'last3_letters': 'ake'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'adjective'),
#  ({'starting_letter': 'I',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'p',
#    'last2_letters': 'ap',
#    'last3_letters': 'cap'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'm',
#    'last2_letters': 'im',
#    'last3_letters': 'rim'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ist'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'l',
#    'last2_letters': 'll',
#    'last3_letters': 'all'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'dly'},
#   'adjective'),
#  ({'starting_letter': 'D',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'ive'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 't',
#    'last2_letters': 'it',
#    'last3_letters': 'lit'},
#   'adjective'),
#  ({'starting_letter': 'V',
#    'last_letter': 't',
#    'last2_letters': 'ct',
#    'last3_letters': 'ect'},
#   'verb'),
#  ({'starting_letter': 'W',
#    'last_letter': 's',
#    'last2_letters': 'ds',
#    'last3_letters': 'eds'},
#   'noun'),
#  ({'starting_letter': 'Y',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'lly'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'e',
#    'last2_letters': 'ue',
#    'last3_letters': 'sue'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'tic'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'l',
#    'last2_letters': 'rl',
#    'last3_letters': 'arl'},
#   'noun'),
#  ({'starting_letter': 'J',
#    'last_letter': 'x',
#    'last2_letters': 'nx',
#    'last3_letters': 'inx'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'her'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'id',
#    'last3_letters': 'aid'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'me',
#    'last3_letters': 'ème'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'vel'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ied'},
#   'adjective'),
#  ({'starting_letter': 'T',
#    'last_letter': 'h',
#    'last2_letters': 'th',
#    'last3_letters': 'fth'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'h',
#    'last2_letters': 'ch',
#    'last3_letters': 'ach'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'set'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'cal'},
#   'adjective'),
#  ({'starting_letter': 'D',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'ke',
#    'last3_letters': 'uke'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'o',
#    'last2_letters': 'co',
#    'last3_letters': 'sco'},
#   'adverb'),
#  ({'starting_letter': 'C',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 'f',
#    'last2_letters': 'ff',
#    'last3_letters': 'aff'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'verb'),
#  ({'starting_letter': 'H',
#    'last_letter': 't',
#    'last2_letters': 'et',
#    'last3_letters': 'net'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'e',
#    'last2_letters': 've',
#    'last3_letters': 'ave'},
#   'verb'),
#  ({'starting_letter': 'T',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'ken'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'y',
#    'last2_letters': 'ty',
#    'last3_letters': 'rty'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'h',
#    'last2_letters': 'ch',
#    'last3_letters': 'ich'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'tly'},
#   'adverb'),
#  ({'starting_letter': 'P',
#    'last_letter': '3',
#    'last2_letters': 'P3',
#    'last3_letters': 'P3'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'n',
#    'last2_letters': 'in',
#    'last3_letters': 'ain'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': '-',
#    'last2_letters': 'o-',
#    'last3_letters': 'co-'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ite'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'dge'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'ad',
#    'last3_letters': 'ead'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'N',
#    'last_letter': 't',
#    'last2_letters': 'wt',
#    'last3_letters': 'owt'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'her'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ble'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'adjective'),
#  ({'starting_letter': 'F',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'sse'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'hic'},
#   'adjective'),
#  ({'starting_letter': 'R',
#    'last_letter': 'a',
#    'last2_letters': 'ra',
#    'last3_letters': 'era'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ble'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'm',
#    'last2_letters': 'am',
#    'last3_letters': 'gam'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ile'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'p',
#    'last2_letters': 'ep',
#    'last3_letters': 'eep'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'ine'},
#   'noun'),
#  ({'starting_letter': 'N',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'ely'},
#   'adverb'),
#  ({'starting_letter': 'U',
#    'last_letter': 't',
#    'last2_letters': 'it',
#    'last3_letters': 'fit'},
#   'adjective'),
#  ({'starting_letter': 'F',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ked'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': 'y',
#    'last2_letters': 'ny',
#    'last3_letters': 'eny'},
#   'adjective'),
#  ({'starting_letter': 'L',
#    'last_letter': 'm',
#    'last2_letters': 'am',
#    'last3_letters': 'oam'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'c',
#    'last2_letters': 'nc',
#    'last3_letters': 'anc'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'p',
#    'last2_letters': 'lp',
#    'last3_letters': 'alp'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ite'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'N',
#    'last_letter': 'n',
#    'last2_letters': 'in',
#    'last3_letters': 'cin'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'd',
#    'last2_letters': 'rd',
#    'last3_letters': 'ard'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'ium'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'noun'),
#  ({'starting_letter': 'N',
#    'last_letter': 'i',
#    'last2_letters': 'zi',
#    'last3_letters': 'azi'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 't',
#    'last2_letters': 'at',
#    'last3_letters': 'eat'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'k',
#    'last2_letters': 'ok',
#    'last3_letters': 'ook'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'der'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ner'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'fly'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ery'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'ct',
#    'last3_letters': 'ect'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'r',
#    'last2_letters': 'ar',
#    'last3_letters': 'lar'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'ene'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'r',
#    'last2_letters': 'ar',
#    'last3_letters': 'lar'},
#   'adjective'),
#  ({'starting_letter': 'T',
#    'last_letter': 'y',
#    'last2_letters': 'ay',
#    'last3_letters': 'way'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'o',
#    'last2_letters': 'do',
#    'last3_letters': '-do'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'p',
#    'last2_letters': 'up',
#    'last3_letters': '-up'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'm',
#    'last2_letters': 'um',
#    'last3_letters': 'ium'},
#   'noun'),
#  ({'starting_letter': 'Q',
#    'last_letter': 'm',
# ...
#  ({'starting_letter': 'L',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ble'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'mon'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 't',
#    'last2_letters': 'ht',
#    'last3_letters': 'ght'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': '1',
#    'last2_letters': 'b1',
#    'last3_letters': 'ub1'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'len'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'lot'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': '1',
#    'last2_letters': 'k1',
#    'last3_letters': 'ck1'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ury'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'h',
#    'last2_letters': 'sh',
#    'last3_letters': 'ish'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'a',
#    'last2_letters': 'ia',
#    'last3_letters': 'sia'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'ine'},
#   'verb'),
#  ({'starting_letter': 'S',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ued'},
#   'adjective'),
#  ({'starting_letter': 'A',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'ran'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'l',
#    'last2_letters': 'wl',
#    'last3_letters': 'awl'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 's',
#    'last2_letters': 'cs',
#    'last3_letters': 'ics'},
#   'noun'),
#  ({'starting_letter': 'E',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'verb'),
#  ({'starting_letter': 'S',
#    'last_letter': 'w',
#    'last2_letters': 'ew',
#    'last3_letters': 'new'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'be',
#    'last3_letters': 'abe'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'ren'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'der'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'een'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ede'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'hus'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'cal'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'ge',
#    'last3_letters': 'age'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ce',
#    'last3_letters': 'ace'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'h',
#    'last2_letters': 'th',
#    'last3_letters': 'lth'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'o',
#    'last2_letters': 'ro',
#    'last3_letters': 'dro'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 't',
#    'last2_letters': 'xt',
#    'last3_letters': 'ext'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': '2',
#    'last2_letters': 'p2',
#    'last3_letters': 'mp2'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'end'},
#   'verb'),
#  ({'starting_letter': 'T',
#    'last_letter': '2',
#    'last2_letters': 'y2',
#    'last3_letters': 'ky2'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'adjective'),
#  ({'starting_letter': 'T',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'C',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'fic'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'c',
#    'last2_letters': 'ic',
#    'last3_letters': 'tic'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'k',
#    'last2_letters': 'ak',
#    'last3_letters': 'eak'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'f',
#    'last2_letters': 'ff',
#    'last3_letters': 'uff'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'per'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'a',
#    'last2_letters': 'ra',
#    'last3_letters': 'ira'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'yss'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'den'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'a',
#    'last2_letters': 'va',
#    'last3_letters': 'ava'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'p',
#    'last2_letters': 'ip',
#    'last3_letters': 'rip'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 't',
#    'last2_letters': 'ot',
#    'last3_letters': 'oot'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'fon'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'a',
#    'last2_letters': 'ea',
#    'last3_letters': 'Tea'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'y',
#    'last2_letters': 'ly',
#    'last3_letters': 'tly'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'w',
#    'last2_letters': 'ow',
#    'last3_letters': 'dow'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'ned'},
#   'adjective'),
#  ({'starting_letter': 'J',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ery'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': '-',
#    'last2_letters': 'o-',
#    'last3_letters': 'ro-'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 's',
#    'last2_letters': 'ss',
#    'last3_letters': 'ess'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 're',
#    'last3_letters': 'ure'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'e',
#    'last2_letters': 'oe',
#    'last3_letters': 'toe'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': '-',
#    'last2_letters': 'r-',
#    'last3_letters': 'er-'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'oon'},
#   'noun'),
#  ({'starting_letter': 'B',
#    'last_letter': 'e',
#    'last2_letters': 'ie',
#    'last3_letters': 'rie'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'une'},
#   'adjective'),
#  ({'starting_letter': 'L',
#    'last_letter': 't',
#    'last2_letters': 'st',
#    'last3_letters': 'ast'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'ese'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'b',
#    'last2_letters': 'mb',
#    'last3_letters': 'amb'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'Per'},
#   'verb'),
#  ({'starting_letter': 'F',
#    'last_letter': '1',
#    'last2_letters': 'e1',
#    'last3_letters': 'se1'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'her'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': '1',
#    'last2_letters': 't1',
#    'last3_letters': 'et1'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'cle'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'i',
#    'last2_letters': 'Ai',
#    'last3_letters': 'Ai'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'k',
#    'last2_letters': 'ok',
#    'last3_letters': 'ook'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ble'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': '2',
#    'last2_letters': 'r2',
#    'last3_letters': 'er2'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': '2',
#    'last2_letters': 't2',
#    'last3_letters': 'nt2'},
#   'verb'),
#  ({'starting_letter': 'A',
#    'last_letter': 'k',
#    'last2_letters': 'sk',
#    'last3_letters': 'Ask'},
#   'verb'),
#  ({'starting_letter': 'I',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'n',
#    'last2_letters': 'an',
#    'last3_letters': 'can'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'e',
#    'last2_letters': 'de',
#    'last3_letters': 'ide'},
#   'noun'),
#  ({'starting_letter': 'O',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'and'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'red'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'l',
#    'last2_letters': 'al',
#    'last3_letters': 'mal'},
#   'adjective'),
#  ({'starting_letter': 'F',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'O',
#    'last_letter': 'y',
#    'last2_letters': 'hy',
#    'last3_letters': 'phy'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'h',
#    'last2_letters': 'gh',
#    'last3_letters': 'igh'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'hed'},
#   'adjective'),
#  ({'starting_letter': 'U',
#    'last_letter': 'd',
#    'last2_letters': 'ed',
#    'last3_letters': 'led'},
#   'adjective'),
#  ({'starting_letter': 'O',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ory'},
#   'adjective'),
#  ({'starting_letter': 'H',
#    'last_letter': 'y',
#    'last2_letters': 'ay',
#    'last3_letters': 'day'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'dus'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'nry'},
#   'noun'),
#  ({'starting_letter': 'T',
#    'last_letter': 'e',
#    'last2_letters': 'ce',
#    'last3_letters': 'nce'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'e',
#    'last2_letters': 'ne',
#    'last3_letters': 'one'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 's',
#    'last2_letters': 'és',
#    'last3_letters': 'tés'},
#   'noun'),
#  ({'starting_letter': 'M',
#    'last_letter': 't',
#    'last2_letters': 'at',
#    'last3_letters': 'eat'},
#   'noun'),
#  ({'starting_letter': 'L',
#    'last_letter': 'd',
#    'last2_letters': '.d',
#    'last3_letters': 't.d'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'h',
#    'last2_letters': 'th',
#    'last3_letters': 'ath'},
#   'adjective'),
#  ({'starting_letter': 'D',
#    'last_letter': 'n',
#    'last2_letters': 'on',
#    'last3_letters': 'ion'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'n',
#    'last2_letters': 'en',
#    'last3_letters': 'ten'},
#   'verb'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ale'},
#   'noun'),
#  ({'starting_letter': 'A',
#    'last_letter': 'm',
#    'last2_letters': 'sm',
#    'last3_letters': 'ism'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'l',
#    'last2_letters': 'ol',
#    'last3_letters': 'tol'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ant'},
#   'adjective'),
#  ({'starting_letter': 'N',
#    'last_letter': 's',
#    'last2_letters': 'us',
#    'last3_letters': 'ous'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': '3',
#    'last2_letters': 'b3',
#    'last3_letters': 'ob3'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'r',
#    'last2_letters': 'ar',
#    'last3_letters': 'Far'},
#   'adverb'),
#  ({'starting_letter': 'H',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'adjective'),
#  ({'starting_letter': 'G',
#    'last_letter': '2',
#    'last2_letters': 'l2',
#    'last3_letters': 'll2'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'C',
#    'last_letter': 'y',
#    'last2_letters': 'ry',
#    'last3_letters': 'ary'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'j',
#    'last2_letters': 'Sj',
#    'last3_letters': 'Sj'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'per'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'C',
#    'last_letter': 'b',
#    'last2_letters': 'ab',
#    'last3_letters': 'Cab'},
#   'noun'),
#  ({'starting_letter': 'F',
#    'last_letter': 'e',
#    'last2_letters': 'ee',
#    'last3_letters': 'ree'},
#   'noun'),
#  ({'starting_letter': 'R',
#    'last_letter': 'm',
#    'last2_letters': 'sm',
#    'last3_letters': 'ism'},
#   'noun'),
#  ({'starting_letter': 'G',
#    'last_letter': 'l',
#    'last2_letters': 'el',
#    'last3_letters': 'vel'},
#   'noun'),
#  ({'starting_letter': 'I',
#    'last_letter': 'e',
#    'last2_letters': 'le',
#    'last3_letters': 'ble'},
#   'adjective'),
#  ({'starting_letter': 'P',
#    'last_letter': 'r',
#    'last2_letters': 'er',
#    'last3_letters': 'ter'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'B',
#    'last_letter': 'y',
#    'last2_letters': 'ey',
#    'last3_letters': 'ley'},
#   'noun'),
#  ({'starting_letter': 'S',
#    'last_letter': 'y',
#    'last2_letters': 'vy',
#    'last3_letters': 'rvy'},
#   'noun'),
#  ({'starting_letter': 'W',
#    'last_letter': 'e',
#    'last2_letters': 'se',
#    'last3_letters': 'use'},
#   'noun'),
#  ({'starting_letter': 'D',
#    'last_letter': 'k',
#    'last2_letters': 'nk',
#    'last3_letters': 'ink'},
#   'noun'),
#  ({'starting_letter': 'U',
#    'last_letter': 'g',
#    'last2_letters': 'ng',
#    'last3_letters': 'ing'},
#   'adjective'),
#  ({'starting_letter': 'A',
#    'last_letter': 't',
#    'last2_letters': 'nt',
#    'last3_letters': 'ent'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'e',
#    'last2_letters': 'ke',
#    'last3_letters': 'ike'},
#   'noun'),
#  ({'starting_letter': 'H',
#    'last_letter': 'd',
#    'last2_letters': 'nd',
#    'last3_letters': 'and'},
#   'noun'),
#  ({'starting_letter': 'P',
#    'last_letter': 'e',
#    'last2_letters': 'te',
#    'last3_letters': 'ate'},
#   'verb'),
#  ({'starting_letter': 'P',
#    'last_letter': 'h',
#    'last2_letters': 'sh',
#    'last3_letters': 'ish'},
#   'adjective'),
#  ...]

# %%
set_size = len(featuresets)

# %%
train_set, test_set = featuresets[set_size//2:], featuresets[:set_size//2]

# %%
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
print(nltk.classify.accuracy(classifier, test_set))
# Out:
# 0.7689286493563168
